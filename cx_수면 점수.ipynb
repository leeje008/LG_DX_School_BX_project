# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
plt.rc('font', family = 'Malgun Gothic')

# %%
dum = pd.Series([64.7, 68.9, 73.5, 80.1, 82.1, 83.3], index = [2024, 2025, 2026, 2027, 2028, 2029])

# %%
dum.plot(kind='line', xlabel = '\nCX - 수면 점수' , ylim = (60, 90), color = 'pink')
# Out:
# <Axes: xlabel='\nCX - 수면 점수'>
