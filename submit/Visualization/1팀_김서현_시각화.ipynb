# %% [markdown]
# ## 스마트 가전 리뷰 시각화

# %%
import pickle
import pandas as pd

# %%
with open( "final_smart_review.pickle", "rb" ) as file:
    smart = pickle.load(file)

# %%
from konlpy.tag import Okt

# %%
okt = Okt()

# %%
# 불용어가 저장되어 있는 텍스트 파일 로드
file_path = 'stopword.txt'

# 불용어 파일을 읽어서 set 형태로 저장
with open(file_path, 'r', encoding='utf-8') as f:
    stopwords = set([word.strip() for word in f.readlines()])

# %% [markdown]
# ### 별점 기준으로 긍정리뷰 부정리뷰 분리

# %%
# 데이터 타입 실수로 변경
smart['별점'] = smart['별점'].astype('float32')

# %%
neg_df = smart[(smart['별점'] <= 2.5)]
pos_df = smart[(smart['별점'] >= 4)]

# %% [markdown]
# ### 불용어 처리 함수 정의

# %%
def okt_pos_tagging(string):
    pos_words = okt.pos(string, stem=True, norm=True)
    words = [word for word, tag in pos_words if tag in ['Adjective','Noun'] if word not in stopwords]
    return words

# %% [markdown]
# ### 긍정리뷰

# %%
# 형용사만 추출
def okt_pos_tagging(string):
    pos_words = okt.pos(string, stem=True, norm=True)
    words = [word for word, tag in pos_words if tag in ['Adjective'] if word not in stopwords]
    return words

# %%
cleaned_contents_list = []

for content in pos_df['내용']:
    # 공백 및 줄바꿈 제거
    cleaned_content = content.strip()  # 양쪽 공백 제거
    
    # 연속된 공백을 단일 공백으로 변환
    cleaned_content = ' '.join(cleaned_content.split())
    
    cleaned_contents_list.append(cleaned_content)

# %%
#추출된 단어들을 저장할 리스트
extracted_words_list = []

# cleaned_contents_list에 있는 각 텍스트에 대해 okt_pos_tagging 함수 호출하여 추출된 단어들 리스트에 저장
for text in cleaned_contents_list:
    extracted_words = okt_pos_tagging(text)
    extracted_words_list.append(extracted_words)

# 저장된 추출된 단어들 리스트 출력
for idx, extracted_words in enumerate(extracted_words_list, start=1):
    print(f'추출된 단어들: {extracted_words}')
    print()
# Out:
# 추출된 단어들: ['좋다', '편하다', '좋다']
#
# 추출된 단어들: ['시원하다', '좋다', '깔끔하다']
#
# 추출된 단어들: ['조용하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['빠르다', '좋다', '시원하다', '조용하다']
#
# 추출된 단어들: ['깔끔하다', '만족하다']
#
# 추출된 단어들: ['편하다', '작다', '좋다', '박하다', '아니다', '아쉽다', '좋다', '시원하다', '좋다', '아니다']
#
# 추출된 단어들: ['만족스럽다']
#
# 추출된 단어들: ['만족스럽다', '비싸다', '편리하다', '번거롭다', '없다', '좋다', '불편하다', '아니다', '없다', '아쉽다']
#
# 추출된 단어들: ['편하다', '시끄럽다', '많다', '아니다']
#
# 추출된 단어들: ['가능하다', '작다', '싫다', '좋다']
#
# 추출된 단어들: ['힘들다', '편리하다']
#
# 추출된 단어들: ['좋다', '편하다', '불편하다', '편하다']
#
# 추출된 단어들: ['귀찮다', '편하다', '없다', '원하다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다', '멀다', '불편하다']
#
# 추출된 단어들: ['간단하다', '불편하다', '편하다', '좋아하다']
#
# 추출된 단어들: ['번거롭다', '만족스럽다', '정확하다']
#
# 추출된 단어들: ['평평하다', '아니다', '둥그스름하다', '편하다', '가능하다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '쾌적하다', '아쉽다', '비싸다']
#
# 추출된 단어들: ['솔직하다', '친절하다']
#
# 추출된 단어들: ['완전하다', '깔끔하다']
#
# 추출된 단어들: ['불편하다', '힘들다', '약하다', '만족하다']
#
# 추출된 단어들: ['힘들다', '연결하다', '편하다', '연결하다', '어렵다', '친절하다', '좋다', '귀찮다']
#
# 추출된 단어들: ['안되다', '안되다', '편하다', '오래되다', '만족하다', '친절하다', '좋다']
#
# 추출된 단어들: ['시끄럽다', '간편하다', '좋다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['엄청나다', '불안정하다', '없다', '안되다', '비싸다', '가능하다', '슬프다']
#
# 추출된 단어들: ['안되다', '불편하다', '만족하다']
#
# 추출된 단어들: ['약하다', '약하다']
#
# 추출된 단어들: ['답답하다', '쎄다']
#
# 추출된 단어들: ['답답하다', '괜찮다', '좋다', '수월하다', '다르다', '좋다']
#
# 추출된 단어들: ['멀다', '편리하다', '좋다']
#
# 추출된 단어들: ['멀다', '좋다']
#
# 추출된 단어들: ['귀찮다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '멀다', '좋다']
#
# 추출된 단어들: ['좋다', '편하다', '좋아하다']
#
# 추출된 단어들: ['어렵다']
#
# 추출된 단어들: ['비싸다', '편하다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다', '괜찮다', '연결하다', '부족하다', '그렇다', '연결하다']
#
# 추출된 단어들: ['편하다', '깔끔하다', '예쁘다', '비싸다', '만족하다']
#
# 추출된 단어들: ['멀다', '귀찮다', '편하다']
#
# 추출된 단어들: ['간편하다', '그렇다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다', '만족스럽다']
#
# 추출된 단어들: ['탁월하다', '깔끔하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '편리하다', '느리다', '만족하다']
#
# 추출된 단어들: ['이쁘다', '이쁘다', '편하다']
#
# 추출된 단어들: ['좋다', '많다', '좋다']
#
# 추출된 단어들: ['새롭다', '느리다', '좋다']
#
# 추출된 단어들: ['오래되다', '만족하다', '그렇다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['쓸쓸하다', '캄캄하다', '쓸쓸하다', '좋다']
#
# 추출된 단어들: ['만족하다', '안되다', '아쉽다', '안되다', '연결하다', '안되다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['쉽다', '좋다', '힘들다']
#
# 추출된 단어들: ['신기하다', '없다', '가능하다']
#
# 추출된 단어들: ['좋다', '어렵다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '상관없다']
#
# 추출된 단어들: ['쉽다', '아쉽다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '없다', '좋다', '좋다', '좋다', '즐겁다']
#
# 추출된 단어들: ['깔끔하다', '재밌다', '좋다', '편하다', '만족하다']
#
# 추출된 단어들: ['간단하다', '편리하다', '없다', '만족하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['똑똑하다', '편하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['멀다', '편하다']
#
# 추출된 단어들: ['사악하다']
#
# 추출된 단어들: ['귀찮다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['비싸다', '편하다', '좋다', '편하다', '좋다']
#
# 추출된 단어들: ['불편하다', '편하다']
#
# 추출된 단어들: ['솔직하다', '비싸다', '좋다', '많다', '깔끔하다', '좋다', '안되다', '아니다']
#
# 추출된 단어들: ['가능하다', '저렴하다']
#
# 추출된 단어들: ['귀찮다', '귀찮다', '새롭다', '편하다', '안되다', '만족하다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['설치다', '없다', '편하다']
#
# 추출된 단어들: ['귀찮다', '번거롭다', '좋다']
#
# 추출된 단어들: ['원하다', '좋다', '많다', '답답하다']
#
# 추출된 단어들: ['느리다', '아쉽다', '편하다', '좋다', '볼록하다', '아쉽다', '편하다', '좋다']
#
# 추출된 단어들: ['시끄럽다', '편하다', '좋다']
#
# 추출된 단어들: ['시끄럽다', '괜찮다', '편하다', '좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['편리하다', '좋다', '만족하다']
#
# 추출된 단어들: ['알딸딸하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['연결하다', '연결하다', '좋다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다', '편리하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['없다', '편하다']
#
# 추출된 단어들: ['귀찮다', '좋다']
#
# 추출된 단어들: ['좋다', '편하다', '안되다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['만족하다', '귀찮다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['좋다', '불편하다', '많다', '편하다', '좋다', '편하다', '고맙다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['멀다', '편하다', '심하다']
#
# 추출된 단어들: ['좋아하다']
#
# 추출된 단어들: ['쓰리다', '간편하다', '좋다', '저렴하다', '아니다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편리하다', '귀찮다', '굳다', '굳다']
#
# 추출된 단어들: ['미세하다', '확실하다', '깔끔하다', '편하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['멀다', '힘드다', '게으르다', '딱이다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['없다', '아깝다', '아니다', '좋다']
#
# 추출된 단어들: ['간단하다']
#
# 추출된 단어들: ['시끄럽다', '가능하다', '좋다']
#
# 추출된 단어들: ['편리하다', '없다']
#
# 추출된 단어들: ['시끄럽다', '아니다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '싫다']
#
# 추출된 단어들: ['편리하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['간편하다', '편리하다']
#
# 추출된 단어들: ['안되다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['비싸다', '없다']
#
# 추출된 단어들: ['깔끔하다', '편하다']
#
# 추출된 단어들: ['느리다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '조용하다', '좋다']
#
# 추출된 단어들: ['없다', '편하다', '좋다']
#
# 추출된 단어들: ['낮다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋아하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편리하다', '깔끔하다', '편리하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['안되다', '깔끔하다', '높다', '나쁘다']
#
# 추출된 단어들: ['연결하다', '가능하다']
#
# 추출된 단어들: ['많다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '간편하다', '좋다', '굳다', '굳다']
#
# 추출된 단어들: ['이쁘다', '좋다', '아니다']
#
# 추출된 단어들: ['좋다', '편리하다']
#
# 추출된 단어들: ['안되다', '편하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['연결하다']
#
# 추출된 단어들: ['시끄럽다', '시끄럽다']
#
# 추출된 단어들: ['없다', '만족스럽다', '뿌듯하다']
#
# 추출된 단어들: ['좋다', '기대하다']
#
# 추출된 단어들: ['귀찮다', '좋다']
#
# 추출된 단어들: ['느리다']
#
# 추출된 단어들: ['연결하다']
#
# 추출된 단어들: ['연결하다', '편리하다', '좋다']
#
# 추출된 단어들: ['만족스럽다']
#
# 추출된 단어들: ['비싸다', '아니다', '만족하다']
#
# 추출된 단어들: ['간단하다', '가능하다', '좋다']
#
# 추출된 단어들: ['안되다', '친절하다', '행복하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['만족스럽다', '저렴하다']
#
# 추출된 단어들: ['연결하다', '없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '빠르다']
#
# 추출된 단어들: ['가능하다']
#
# 추출된 단어들: ['좋아하다', '좋아하다']
#
# 추출된 단어들: ['예쁘다', '예쁘다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀엽다', '좋다', '귀엽다', '예쁘다']
#
# 추출된 단어들: ['가볍다', '편리하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['오래되다', '새롭다', '적당하다', '깨끗하다', '좋다', '좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['귀엽다', '부실하다', '뛰어나다', '귀찮다', '없다', '없다', '뛰어나다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['예쁘다', '편하다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다', '좋다']
#
# 추출된 단어들: ['괜찮다', '괜찮다']
#
# 추출된 단어들: ['자세하다', '좋다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '적절하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['안되다', '답답하다', '좋다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['이쁘다', '깔끔하다', '다양하다', '편리하다']
#
# 추출된 단어들: ['작다']
#
# 추출된 단어들: ['새롭다', '자세하다', '좋다']
#
# 추출된 단어들: ['간편하다']
#
# 추출된 단어들: ['가볍다', '예쁘다', '좋다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['필요하다', '이쁘다', '다양하다', '좋다']
#
# 추출된 단어들: ['정확하다', '얇다', '예쁘다', '만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '가볍다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '좋다', '이쁘다', '아니다']
#
# 추출된 단어들: ['편리하다', '편하다']
#
# 추출된 단어들: ['아니다', '중요하다']
#
# 추출된 단어들: ['빨르다', '편하다', '좋다', '깔끔하다']
#
# 추출된 단어들: ['정확하다', '깔끔하다']
#
# 추출된 단어들: ['좋다', '쉽다', '빠르다']
#
# 추출된 단어들: ['좋다', '다양하다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '자세하다', '좋다']
#
# 추출된 단어들: ['착하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '튼튼하다']
#
# 추출된 단어들: ['좋아하다']
#
# 추출된 단어들: ['안되다']
#
# 추출된 단어들: ['예쁘다', '자세하다', '좋다']
#
# 추출된 단어들: ['간단하다', '편하다', '귀찮다', '충분하다']
#
# 추출된 단어들: ['헷갈리다', '이쁘다']
#
# 추출된 단어들: ['필요하다', '깔끔하다', '이쁘다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['연결하다', '편하다', '많다', '좋다', '유용하다', '묵직하다', '좋다', '당연하다', '좋다', '추하다']
#
# 추출된 단어들: ['없다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다', '이쁘다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '정확하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '어색하다']
#
# 추출된 단어들: ['쉽다', '깔끔하다', '간단하다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '연결하다', '안되다', '연결하다', '편리하다']
#
# 추출된 단어들: ['튼튼하다', '좋다', '그렇다']
#
# 추출된 단어들: ['좋다', '가볍다', '없다', '좋다', '작다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['가볍다', '좋다', '적당하다']
#
# 추출된 단어들: ['안되다', '이쁘다', '예쁘다']
#
# 추출된 단어들: ['편하다', '연결하다', '좋다']
#
# 추출된 단어들: ['연결하다', '편하다']
#
# 추출된 단어들: ['이상하다', '아니다', '높다']
#
# 추출된 단어들: ['부족하다', '많다', '좋다']
#
# 추출된 단어들: ['이쁘다', '정확하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['필요하다', '좋다', '빠르다', '저렴하다', '좋다']
#
# 추출된 단어들: ['불편하다', '만족하다']
#
# 추출된 단어들: ['귀찮다', '없다']
#
# 추출된 단어들: ['자세하다', '좋다', '좋다']
#
# 추출된 단어들: ['싫다', '예쁘다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['평평하다', '정확하다', '그렇다', '다르다']
#
# 추출된 단어들: ['자세하다']
#
# 추출된 단어들: ['만족하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['어렵다', '간략하다', '좋다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다', '좋다', '쓸데없다', '이쁘다']
#
# 추출된 단어들: ['연결하다', '저렴하다', '괜찮다']
#
# 추출된 단어들: ['빠르다', '좋다', '작다', '좋다', '작다']
#
# 추출된 단어들: ['빠르다', '좋다', '신기하다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '정확하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['튼튼하다', '좋다', '좋다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다', '깔끔하다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['없다', '깔끔하다', '만족스럽다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['연결하다', '간편하다', '좋다']
#
# 추출된 단어들: ['빠르다', '필요하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['편리하다', '가볍다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['저렴하다']
#
# 추출된 단어들: ['깔끔하다', '귀엽다', '좋다']
#
# 추출된 단어들: ['많다', '괜찮다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '좋다', '얇다', '가볍다', '좋다']
#
# 추출된 단어들: ['많다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '깔끔하다']
#
# 추출된 단어들: ['착하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다']
#
# 추출된 단어들: ['정확하다', '딱하다', '중요하다', '정확하다']
#
# 추출된 단어들: ['정확하다', '편하다', '좋다', '정확하다']
#
# 추출된 단어들: ['편하다', '가능하다', '좋다']
#
# 추출된 단어들: ['안되다', '심하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '빠르다', '만족스럽다']
#
# 추출된 단어들: ['편하다', '좋다', '예쁘다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['여전하다', '좋다']
#
# 추출된 단어들: ['좋다', '없다', '밉다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['용하다', '편하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['굳다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가볍다', '좋다', '만족하다']
#
# 추출된 단어들: ['저렴하다', '좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '용이하다', '좋다']
#
# 추출된 단어들: ['정확하다', '가볍다', '좋다']
#
# 추출된 단어들: ['아담하다', '깔끔하다', '괜찮다', '기대하다', '만족스럽다']
#
# 추출된 단어들: ['좋다', '아니다', '없다', '만족하다']
#
# 추출된 단어들: ['필요하다', '급하다', '이쁘다', '착하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '예쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '편하다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: ['간편하다', '가능하다']
#
# 추출된 단어들: ['복잡하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['살찌다', '좋다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['연결하다', '가능하다', '아니다', '편리하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['예쁘다', '편하다']
#
# 추출된 단어들: ['좋다', '정확하다']
#
# 추출된 단어들: ['편하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '괜찮다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '적당하다']
#
# 추출된 단어들: ['좋다', '튼튼하다', '이쁘다']
#
# 추출된 단어들: ['확실하다', '얇다']
#
# 추출된 단어들: ['예쁘다', '가능하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '편리하다']
#
# 추출된 단어들: ['가볍다', '좋다']
#
# 추출된 단어들: ['확실하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['필요하다', '이쁘다', '가볍다', '좋다']
#
# 추출된 단어들: ['가볍다', '좋다', '깔끔하다', '이쁘다']
#
# 추출된 단어들: ['그렇다', '착하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['아담하다', '이뿌다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다', '정확하다']
#
# 추출된 단어들: ['안되다', '적합하다']
#
# 추출된 단어들: ['오래되다', '귀엽다', '앙증맞다', '상관없다', '깔끔하다', '괜찮다']
#
# 추출된 단어들: ['좋다', '좋다', '불필요하다', '좋다']
#
# 추출된 단어들: ['가볍다', '좋다', '연결하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '만족스럽다']
#
# 추출된 단어들: ['좋다', '딱하다', '연결하다', '가능하다', '좋다']
#
# 추출된 단어들: ['정확하다', '민망하다', '안되다', '정확하다', '그렇다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다', '예쁘다', '무겁다', '좋다', '차갑다', '없다', '좋다', '평범하다', '아니다']
#
# 추출된 단어들: ['불편하다', '좋다']
#
# 추출된 단어들: ['만족하다', '신기하다', '좋다']
#
# 추출된 단어들: ['좋다', '가능하다', '좋다', '좋다', '좋다']
#
# 추출된 단어들: ['낮다', '좋다']
#
# 추출된 단어들: ['빨르다', '좋다', '가능하다', '쓰리다', '정확하다', '정확하다', '후회되다', '만족하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '가볍다']
#
# 추출된 단어들: ['귀엽다', '귀엽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['성공하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['필요하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['가볍다', '좋다']
#
# 추출된 단어들: ['궁금하다', '좋다']
#
# 추출된 단어들: ['저렴하다', '필요하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '편하다', '만족하다']
#
# 추출된 단어들: ['깔끔하다', '편하다']
#
# 추출된 단어들: ['좋다', '예쁘다', '좋다']
#
# 추출된 단어들: ['알맞다', '예쁘다', '깔끔하다']
#
# 추출된 단어들: ['슬프다']
#
# 추출된 단어들: ['의심스럽다']
#
# 추출된 단어들: ['밉다', '덥다', '괜찮다']
#
# 추출된 단어들: ['그렇다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['없다', '높다', '좋아하다']
#
# 추출된 단어들: ['예쁘다', '정확하다']
#
# 추출된 단어들: ['아니다', '편리하다', '빨르다', '만족하다']
#
# 추출된 단어들: ['없다', '가볍다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['가볍다', '편하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['빨르다', '깔끔하다', '좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['편리하다', '많다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '편리하다']
#
# 추출된 단어들: ['좋다', '자세하다', '좋다', '만족하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['좋다', '솔직하다', '다르다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '깔끔하다', '편하다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['이뿌다', '간단하다']
#
# 추출된 단어들: ['좋다', '저렴하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['아니다', '번거롭다', '없다']
#
# 추출된 단어들: ['아담하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['적당하다', '좋다']
#
# 추출된 단어들: ['유용하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '만족하다']
#
# 추출된 단어들: ['서툴다', '그렇다', '좋다']
#
# 추출된 단어들: ['비싸다', '편하다']
#
# 추출된 단어들: ['좋다', '좋다', '편하다', '수월하다']
#
# 추출된 단어들: ['유용하다']
#
# 추출된 단어들: ['이쁘다', '좋다', '간편하다', '편리하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['쉽다', '아니다', '어렵다', '편하다', '만족스럽다']
#
# 추출된 단어들: ['멀다', '귀찮다', '편하다', '깔끔하다']
#
# 추출된 단어들: ['안되다']
#
# 추출된 단어들: ['예쁘다', '좋다', '비싸다']
#
# 추출된 단어들: ['작다', '편리하다']
#
# 추출된 단어들: ['간편하다', '만족스럽다', '조용하다', '덥다', '괜찮다']
#
# 추출된 단어들: ['강하다', '원하다', '원하다', '톡톡하다', '이쁘다', '만족스럽다']
#
# 추출된 단어들: ['무겁다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['안되다', '편하다', '좋다', '시끄럽다', '좋다']
#
# 추출된 단어들: ['가능하다', '시원하다', '예쁘다', '넓다']
#
# 추출된 단어들: ['부드럽다', '원하다', '균일하다', '깔끔하다']
#
# 추출된 단어들: ['적당하다', '시원하다', '좋다', '없다', '편리하다']
#
# 추출된 단어들: ['편하다', '약하다', '가깝다', '강하다', '조용하다', '좋다', '예민하다']
#
# 추출된 단어들: ['확실하다', '시원하다', '좋다', '안되다', '시원하다']
#
# 추출된 단어들: ['편하다', '가능하다', '예쁘다', '만족스럽다', '시원하다', '없다', '가능하다', '섬세하다', '작다']
#
# 추출된 단어들: ['좋다', '은은하다', '좋다', '넓다', '좋다', '예쁘다', '간편하다', '무겁다', '좋다', '좋다', '만족하다']
#
# 추출된 단어들: ['편리하다', '좋다', '편하다', '원하다', '가능하다', '좋다', '덥다', '시원하다', '좋다', '덥다', '강하다', '좋다', '싫다', '약하다', '좋다', '좋다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['빠르다', '만족하다', '시원하다']
#
# 추출된 단어들: ['편하다', '덥다', '덥다', '시원하다', '좋다', '쎄다', '만족하다']
#
# 추출된 단어들: ['좋다', '좋다', '지저분하다']
#
# 추출된 단어들: ['강력하다', '좋다', '편리하다']
#
# 추출된 단어들: ['안좋다', '굉장하다', '만족하다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['강하다', '좋다']
#
# 추출된 단어들: ['필요없다', '좋다']
#
# 추출된 단어들: ['없다', '좋다']
#
# 추출된 단어들: ['조용하다', '쎄다', '저렴하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가능하다', '가능하다', '시원하다']
#
# 추출된 단어들: ['없다', '시원하다', '아니다', '확실하다']
#
# 추출된 단어들: ['안되다', '친절하다', '조용하다', '쎄다', '연결하다']
#
# 추출된 단어들: ['그렇다', '편하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['아니다', '많다', '좋다', '쎄다', '아쉽다', '아쉽다', '원하다', '강하다', '좋다']
#
# 추출된 단어들: ['약하다', '강하다', '저렴하다', '예쁘다', '튼튼하다']
#
# 추출된 단어들: ['부족하다']
#
# 추출된 단어들: ['낮다', '딱이다', '빠르다']
#
# 추출된 단어들: ['세련되다', '좋다', '쎄다']
#
# 추출된 단어들: ['없다', '편하다', '작다', '빨르다', '만족하다']
#
# 추출된 단어들: ['없다', '장하다', '만족하다', '미흡하다', '아쉽다', '그렇다', '많다', '시원하다', '조용하다', '없다']
#
# 추출된 단어들: ['좋다', '없다']
#
# 추출된 단어들: ['시원하다', '좋다', '무겁다']
#
# 추출된 단어들: ['그렇다', '번거롭다', '없다', '섭섭하다']
#
# 추출된 단어들: ['안되다', '빠르다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다', '괜찮다', '괜찮다', '편리하다', '편하다', '편하다', '시원하다', '조용하다', '좋다']
#
# 추출된 단어들: ['필요하다', '빠르다', '꼼꼼하다', '간편하다', '확실하다', '시원하다', '아니다', '시끄럽다', '조용하다', '조용하다']
#
# 추출된 단어들: ['편하다', '좋다', '편하다', '편하다', '가능하다', '가능하다', '아니다', '가능하다', '바쁘다', '그렇다']
#
# 추출된 단어들: ['당연하다', '편하다', '만족하다']
#
# 추출된 단어들: ['불편하다', '강력하다', '편리하다', '만족하다']
#
# 추출된 단어들: ['시원하다', '간편하다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '좋다', '만족하다']
#
# 추출된 단어들: ['시원하다', '중요하다', '좋다', '좋다', '가능하다']
#
# 추출된 단어들: ['빠르다', '편하다', '좋다', '시원하다', '좋다']
#
# 추출된 단어들: ['불편하다', '광범위하다', '좋다', '빠르다']
#
# 추출된 단어들: ['편하다', '가능하다', '시원하다', '덥다', '쾌적하다', '예민하다', '조용하다', '자유롭다', '편하다']
#
# 추출된 단어들: ['가능하다', '계시다', '가능하다', '놀랍다', '편리하다', '확실하다', '많다', '좋다', '미세하다', '가능하다', '가능하다', '만족하다']
#
# 추출된 단어들: ['귀엽다', '없다', '귀찮다', '가능하다', '똑똑하다']
#
# 추출된 단어들: ['덥다', '좋다', '좋다', '불편하다']
#
# 추출된 단어들: ['다양하다']
#
# 추출된 단어들: ['없다', '좋다', '충분하다', '편하다', '없다', '조용하다']
#
# 추출된 단어들: ['편하다', '쎄다', '좋다', '확실하다', '시원하다', '가능하다']
#
# 추출된 단어들: ['편리하다', '편하다']
#
# 추출된 단어들: ['좋다', '가능하다', '원하다', '편리하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['연결하다', '좋다']
#
# 추출된 단어들: ['가능하다', '편리하다', '없다']
#
# 추출된 단어들: ['필요없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '다양하다', '좋다', '심하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['어렵다', '귀찮다', '만족하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['만족하다', '가능하다', '가능하다', '만족하다', '추하다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['좋다', '유용하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['새롭다']
#
# 추출된 단어들: ['편리하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['연결하다', '헷갈리다', '어렵다', '편리하다']
#
# 추출된 단어들: ['다르다', '편리하다', '좋다', '어둡다', '편리하다', '필요하다']
#
# 추출된 단어들: ['좋다', '편하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['설치다']
#
# 추출된 단어들: ['만족하다', '가능하다', '연결하다', '가능하다', '편하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['편하다', '가능하다', '좋다', '만족스럽다']
#
# 추출된 단어들: ['높다', '만족하다']
#
# 추출된 단어들: ['은은하다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['빨르다', '꼼꼼하다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['불편하다']
#
# 추출된 단어들: ['연결하다', '원하다', '가능하다', '자유롭다', '편하다']
#
# 추출된 단어들: ['좋다', '빠르다', '만족스럽다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['가능하다', '편리하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '편리하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['느리다', '그렇다']
#
# 추출된 단어들: ['묵직하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['안되다', '아쉽다', '다양하다', '좋다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['정확하다', '안좋다']
#
# 추출된 단어들: ['연결하다', '꾸준하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['연결하다', '좋다', '똑같다']
#
# 추출된 단어들: ['좋다', '좋다', '좋다']
#
# 추출된 단어들: ['느리다', '아니다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['사악하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '꾸준하다']
#
# 추출된 단어들: ['없다', '곱다']
#
# 추출된 단어들: ['고급스럽다', '귀엽다', '만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['비싸다', '다르다', '없다']
#
# 추출된 단어들: ['유용하다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다', '살빼다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '슬프다']
#
# 추출된 단어들: ['바쁘다', '만족하다', '정확하다', '좋다', '정확하다', '당연하다']
#
# 추출된 단어들: ['깔끔하다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['멀다', '비싸다']
#
# 추출된 단어들: ['편하다', '좋다', '좋다']
#
# 추출된 단어들: ['없다', '아니다', '편하다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['빠르다', '편하다']
#
# 추출된 단어들: ['확실하다', '편하다']
#
# 추출된 단어들: ['빠르다', '간편하다', '좋다']
#
# 추출된 단어들: ['귀찮다', '편하다', '조그맣다', '편하다']
#
# 추출된 단어들: ['편하다', '느리다']
#
# 추출된 단어들: ['유용하다', '편리하다']
#
# 추출된 단어들: ['대단하다', '좋다', '용이하다']
#
# 추출된 단어들: ['앙증맞다', '편하다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['좋다', '괜찮다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['깔끔하다', '빠르다', '안되다']
#
# 추출된 단어들: ['아니다', '작다', '나쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다', '좋다', '가볍다', '싫다', '예쁘다']
#
# 추출된 단어들: ['적당하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['조잡하다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['밉다', '야하다']
#
# 추출된 단어들: ['새롭다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['좋다', '빠르다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '연결하다', '밉다']
#
# 추출된 단어들: ['좋다', '빠르다', '좋다']
#
# 추출된 단어들: ['좋아하다', '깔끔하다', '이쁘다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['치밀하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '저렴하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['좋다', '아담하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['유명하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '그렇다']
#
# 추출된 단어들: ['좋다', '괜찮다']
#
# 추출된 단어들: ['이뿌다', '괜찮다']
#
# 추출된 단어들: ['작다', '좋다']
#
# 추출된 단어들: ['간단하다', '좋다', '그렇다', '아쉽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['연결하다', '신기하다', '정확하다', '좋다']
#
# 추출된 단어들: ['좋다', '잘맞다']
#
# 추출된 단어들: ['정확하다', '이쁘다']
#
# 추출된 단어들: ['예쁘다', '좋다', '안전하다']
#
# 추출된 단어들: ['좋다', '굳다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '딱하다', '나쁘다', '좋다', '없다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['가볍다', '깔끔하다', '만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['나쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '편하다', '예쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['적당하다', '묵직하다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀찮다', '좋다']
#
# 추출된 단어들: ['작다', '편하다']
#
# 추출된 단어들: ['멀다', '아니다']
#
# 추출된 단어들: ['간단하다', '연결하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '만족하다']
#
# 추출된 단어들: ['화사하다', '이쁘다']
#
# 추출된 단어들: ['신기하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['빠르다', '착하다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '다양하다']
#
# 추출된 단어들: ['정확하다', '이쁘다', '필요없다', '좋다']
#
# 추출된 단어들: ['빠르다', '좋다', '예쁘다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['새롭다', '안전하다', '이쁘다']
#
# 추출된 단어들: ['용하다', '좋다', '재밌다']
#
# 추출된 단어들: ['새롭다']
#
# 추출된 단어들: ['예쁘다', '좋다', '야하다', '불편하다', '예쁘다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['없다', '정확하다', '없다', '좋다', '좋다']
#
# 추출된 단어들: ['빠르다', '귀엽다', '없다']
#
# 추출된 단어들: ['정확하다', '예민하다', '편하다']
#
# 추출된 단어들: ['예쁘다', '딱이다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '만족하다']
#
# 추출된 단어들: ['새롭다', '편하다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['정확하다', '편하다', '좋다', '적당하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['저렴하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다', '쉽다', '좋다']
#
# 추출된 단어들: ['튼튼하다', '정확하다', '예쁘다']
#
# 추출된 단어들: ['예쁘다', '정확하다', '좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['예쁘다', '정확하다']
#
# 추출된 단어들: ['아니다', '귀엽다', '투명하다', '불투명하다']
#
# 추출된 단어들: ['정확하다', '충분하다']
#
# 추출된 단어들: ['빨르다', '편하다', '좋다', '귀엽다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '가능하다', '좋다', '가능하다']
#
# 추출된 단어들: ['없다', '깔끔하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['빠르다', '예쁘다']
#
# 추출된 단어들: ['좋다', '좋아하다']
#
# 추출된 단어들: ['깔끔하다', '괜찮다']
#
# 추출된 단어들: ['원하다', '좋다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['다르다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['예쁘다', '좋다', '좋다']
#
# 추출된 단어들: ['어렵다']
#
# 추출된 단어들: ['좋다', '정확하다']
#
# 추출된 단어들: ['깔끔하다', '견고하다', '없다']
#
# 추출된 단어들: ['가볍다', '좋다', '이쁘다']
#
# 추출된 단어들: ['궁금하다', '좋다']
#
# 추출된 단어들: ['좋다', '예쁘다', '없다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['깨끗하다']
#
# 추출된 단어들: ['영롱하다', '많다']
#
# 추출된 단어들: ['정확하다', '슬프다', '좋다']
#
# 추출된 단어들: ['두렵다']
#
# 추출된 단어들: ['필요하다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['깔끔하다', '편하다']
#
# 추출된 단어들: ['미치다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '안좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['예쁘다', '선명하다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['아니다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '신기하다', '재밌다']
#
# 추출된 단어들: ['빠르다', '그렇다']
#
# 추출된 단어들: ['예쁘다', '안전하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '중요하다', '좋다']
#
# 추출된 단어들: ['빠르다', '확실하다', '평평하다', '정확하다', '정확하다']
#
# 추출된 단어들: ['가능하다', '동일하다', '자세하다', '좋다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['박하다', '예쁘다', '용하다', '좋다']
#
# 추출된 단어들: ['이뿌다', '가볍다', '좋다']
#
# 추출된 단어들: ['예쁘다', '없다', '만족스럽다', '예쁘다']
#
# 추출된 단어들: ['이쁘다', '연결하다', '유용하다']
#
# 추출된 단어들: ['불편하다', '없다']
#
# 추출된 단어들: ['좋다', '일정하다']
#
# 추출된 단어들: ['빠르다', '이쁘다', '없다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['다르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '아니다', '좋다', '귀엽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['아니다', '아쉽다']
#
# 추출된 단어들: ['단순하다', '깔끔하다', '충실하다']
#
# 추출된 단어들: ['깔끔하다', '없다', '정확하다']
#
# 추출된 단어들: ['적당하다', '편하다', '애매하다']
#
# 추출된 단어들: ['다르다', '괜찮다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['기대하다', '예쁘다']
#
# 추출된 단어들: ['빨르다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['편리하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '이쁘다']
#
# 추출된 단어들: ['필요하다', '좋다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '좋다', '예쁘다']
#
# 추출된 단어들: ['가득하다', '좋다', '정확하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['이쁘다', '편하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다', '정확하다']
#
# 추출된 단어들: ['많다', '좋다']
#
# 추출된 단어들: ['작다', '많다', '불편하다']
#
# 추출된 단어들: ['빠르다', '예쁘다', '괜찮다', '좋다']
#
# 추출된 단어들: ['높다', '스럽다', '좋다']
#
# 추출된 단어들: ['귀엽다', '깔끔하다']
#
# 추출된 단어들: ['정확하다', '나쁘다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['예민하다', '좋다']
#
# 추출된 단어들: ['안되다', '예쁘다']
#
# 추출된 단어들: ['예쁘다', '예쁘다']
#
# 추출된 단어들: ['두렵다', '두렵다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['가능하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['예쁘다', '정확하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다', '간단하다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀엽다', '정확하다']
#
# 추출된 단어들: ['좋다', '알맞다', '예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빨르다', '좋다', '예쁘다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '넉넉하다']
#
# 추출된 단어들: ['세련되다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['이쁘다', '가볍다', '그렇다', '불편하다']
#
# 추출된 단어들: ['없다', '안되다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '부드럽다', '이상하다', '우수하다']
#
# 추출된 단어들: ['좋다', '다르다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '작다', '좋다', '정확하다', '좋다']
#
# 추출된 단어들: ['좋다', '힘들다', '좋다']
#
# 추출된 단어들: ['새롭다', '다르다', '없다']
#
# 추출된 단어들: ['좋아하다', '예쁘다', '적당하다', '좋다']
#
# 추출된 단어들: ['빨르다', '정확하다', '만족하다']
#
# 추출된 단어들: ['편하다', '가볍다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가볍다', '예쁘다']
#
# 추출된 단어들: ['이쁘다', '튼튼하다', '빠르다']
#
# 추출된 단어들: ['예쁘다', '깔끔하다']
#
# 추출된 단어들: ['좋다', '깔끔하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '정확하다']
#
# 추출된 단어들: ['필요없다', '편하다']
#
# 추출된 단어들: ['예쁘다', '튼튼하다', '정확하다', '만족하다']
#
# 추출된 단어들: ['불편하다']
#
# 추출된 단어들: ['귀엽다', '만족하다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '좋다', '굳다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['튼튼하다', '좋다']
#
# 추출된 단어들: ['정확하다', '이쁘다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다', '다양하다', '없다']
#
# 추출된 단어들: ['촉촉하다']
#
# 추출된 단어들: ['간편하다', '약하다', '만족하다']
#
# 추출된 단어들: ['만족하다', '간편하다', '좋다']
#
# 추출된 단어들: ['편리하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['건조하다', '깔끔하다', '좋다', '아쉽다', '나쁘다', '연결하다', '없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '이쁘다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: ['좋다', '이쁘다', '편하다']
#
# 추출된 단어들: ['딱좋다', '이쁘다']
#
# 추출된 단어들: ['귀엽다', '많다']
#
# 추출된 단어들: ['만족스럽다', '좋다', '좋다', '가능하다', '성하다', '편하다', '만족하다']
#
# 추출된 단어들: ['적당하다', '편리하다', '은은하다']
#
# 추출된 단어들: ['예쁘다', '완벽하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['없다', '건조하다', '중요하다', '작다', '편하다', '작다', '작다', '귀엽다', '없다']
#
# 추출된 단어들: ['이쁘다', '좋다', '좋다', '간단하다', '없다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['만족하다', '아니다']
#
# 추출된 단어들: ['간단하다', '괜찮다', '좋다', '안되다']
#
# 추출된 단어들: ['편하다', '편하다']
#
# 추출된 단어들: ['불편하다', '가능하다', '가능하다', '편하다']
#
# 추출된 단어들: ['원하다', '원하다', '좋다', '좋다', '간편하다']
#
# 추출된 단어들: ['가능하다', '편하다', '원하다']
#
# 추출된 단어들: ['좋다', '없다', '괜찮다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '좋다', '가능하다', '가능하다']
#
# 추출된 단어들: ['어둡다', '좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다', '연결하다']
#
# 추출된 단어들: ['다양하다', '연결하다', '간편하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '없다', '좋다']
#
# 추출된 단어들: ['따뜻하다', '은은하다', '예쁘다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['실패하다', '연결하다', '편하다']
#
# 추출된 단어들: ['다양하다', '좋다', '편리하다']
#
# 추출된 단어들: ['야하다', '많다', '불편하다', '편하다']
#
# 추출된 단어들: ['없다', '아쉽다', '만족스럽다']
#
# 추출된 단어들: ['좋아하다', '깔끔하다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['편하다', '만족하다']
#
# 추출된 단어들: ['좋다', '나태하다', '편하다']
#
# 추출된 단어들: ['원하다', '좋다', '미세하다', '가능하다']
#
# 추출된 단어들: ['만족스럽다', '가능하다', '귀찮다', '좋다']
#
# 추출된 단어들: ['오래되다', '멀쩡하다', '가능하다', '편하다', '약하다', '유용하다']
#
# 추출된 단어들: ['유용하다', '자유롭다', '만족스럽다', '그렇다', '그렇다']
#
# 추출된 단어들: ['저렴하다', '만족하다', '그렇다', '좋다']
#
# 추출된 단어들: ['편하다', '편리하다', '그렇다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['연결하다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['다양하다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다', '용하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '안되다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가능하다', '좋다', '다양하다', '가능하다', '신기하다', '좋다']
#
# 추출된 단어들: ['유용하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '가능하다', '편하다']
#
# 추출된 단어들: ['편하다', '충분하다', '가능하다']
#
# 추출된 단어들: ['편하다', '괜찮다', '신기하다']
#
# 추출된 단어들: ['많다', '멀다', '불편하다', '편하다', '다양하다', '좋아하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['가능하다', '편리하다']
#
# 추출된 단어들: ['굉장하다', '편리하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['원하다', '좋다', '편하다']
#
# 추출된 단어들: ['편하다', '가능하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['가능하다', '적당하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['가능하다', '편리하다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['다양하다', '편리하다', '다양하다']
#
# 추출된 단어들: ['적정하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['필요하다', '유용하다', '다양하다']
#
# 추출된 단어들: ['가능하다', '미세하다', '좋다']
#
# 추출된 단어들: ['편하다', '유용하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['노랗다', '어둡다', '좋다', '좋다', '연결하다', '헷갈리다', '좋다']
#
# 추출된 단어들: ['번거롭다', '그렇다', '편리하다']
#
# 추출된 단어들: ['좋다', '만족스럽다', '귀찮다', '많다', '그렇다', '없다', '재미있다']
#
# 추출된 단어들: ['저렴하다', '빠르다', '다양하다', '좋다']
#
# 추출된 단어들: ['좋다', '원하다', '다양하다']
#
# 추출된 단어들: ['어렵다', '안되다', '오래되다', '없다', '가능하다', '새롭다', '충분하다', '힘들다', '오래되다', '많다', '그렇다', '가능하다', '고맙다', '가능하다', '가능하다', '좋다', '많다', '충분하다', '아쉽다', '좋다']
#
# 추출된 단어들: ['새롭다', '좋다']
#
# 추출된 단어들: ['유용하다']
#
# 추출된 단어들: ['짧다', '아쉽다', '편하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '가능하다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['착하다']
#
# 추출된 단어들: ['가능하다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['가능하다', '편하다']
#
# 추출된 단어들: ['다양하다', '좋다']
#
# 추출된 단어들: ['가능하다', '편하다']
#
# 추출된 단어들: ['원하다', '원하다', '좋다']
#
# 추출된 단어들: ['아니다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['눈부시다', '편하다', '은은하다', '좋다']
#
# 추출된 단어들: ['편리하다', '가능하다', '좋다']
#
# 추출된 단어들: ['가능하다', '괜찮다', '이쁘다']
#
# 추출된 단어들: ['다양하다', '신기하다', '없다']
#
# 추출된 단어들: ['없다', '편하다']
#
# 추출된 단어들: ['새롭다', '유용하다', '편하다', '없다', '안되다']
#
# 추출된 단어들: ['약하다', '편하다', '좋다', '편하다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['튼튼하다', '예쁘다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다', '저렴하다']
#
# 추출된 단어들: ['편리하다', '적당하다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['좋다', '편하다', '좋다']
#
# 추출된 단어들: ['좋다', '가능하다', '편하다']
#
# 추출된 단어들: ['좋다', '하얗다', '신기하다', '좋다']
#
# 추출된 단어들: ['신기하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['가능하다', '편리하다', '연결하다', '가능하다', '편리하다', '추하다']
#
# 추출된 단어들: ['편하다', '가능하다']
#
# 추출된 단어들: ['다양하다']
#
# 추출된 단어들: ['만족하다', '다르다', '그렇다']
#
# 추출된 단어들: ['편하다', '다양하다', '좋다']
#
# 추출된 단어들: ['원하다', '편리하다', '좋다']
#
# 추출된 단어들: ['빨르다', '튼튼하다']
#
# 추출된 단어들: ['편리하다', '가능하다', '섬세하다', '가능하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '빠르다', '좋다']
#
# 추출된 단어들: ['다양하다', '가능하다']
#
# 추출된 단어들: ['원하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깊다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['확실하다', '편하다', '좋다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['원하다', '좋다', '아늑하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편리하다', '힘들다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다', '편하다', '자유롭다', '좋다']
#
# 추출된 단어들: ['신기하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['유용하다']
#
# 추출된 단어들: ['저렴하다', '좋다', '편하다']
#
# 추출된 단어들: ['이쁘다', '좋다', '빠르다', '만족하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['다양하다']
#
# 추출된 단어들: ['노랗다', '좋다']
#
# 추출된 단어들: ['편하다', '편하다', '다양하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀찮다', '편하다']
#
# 추출된 단어들: ['신기하다']
#
# 추출된 단어들: ['귀찮다']
#
# 추출된 단어들: ['빠르다', '연결하다']
#
# 추출된 단어들: ['확실하다', '편하다', '좋다']
#
# 추출된 단어들: ['만족하다', '좋다']
#
# 추출된 단어들: ['좋다', '아깝다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['간단하다', '다양하다', '드라마틱하다', '좋다']
#
# 추출된 단어들: ['연결하다', '어둡다', '충분하다', '침침하다', '다양하다']
#
# 추출된 단어들: ['후회되다', '어두컴컴하다', '힘들다', '다양하다', '좋다', '귀찮다', '만족하다', '적합하다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['불안하다', '좋다', '편하다', '좋다']
#
# 추출된 단어들: ['빠르다', '예쁘다']
#
# 추출된 단어들: ['후회되다', '편하다', '추하다']
#
# 추출된 단어들: ['미치다', '좋아하다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다', '아쉽다', '재밌다', '확실하다', '따뜻하다', '가능하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다', '빨갛다']
#
# 추출된 단어들: ['신기하다', '좋다', '은은하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['저렴하다', '저렴하다', '그렇다']
#
# 추출된 단어들: ['다양하다', '좋다']
#
# 추출된 단어들: ['굉장하다', '만족스럽다']
#
# 추출된 단어들: ['많다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '친절하다', '불편하다', '만족하다']
#
# 추출된 단어들: ['설치다', '어렵다', '좋다', '만족스럽다']
#
# 추출된 단어들: ['힘들다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['만족하다', '어렵다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['잘맞다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['다르다', '좋다', '간단하다', '좋다']
#
# 추출된 단어들: ['친절하다', '만족하다']
#
# 추출된 단어들: ['좋다', '필요하다']
#
# 추출된 단어들: ['빠르다', '덥다', '편하다', '좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['높다', '간편하다', '좋다']
#
# 추출된 단어들: ['설치다', '어렵다', '느슨하다', '상관없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['저렴하다', '비싸다']
#
# 추출된 단어들: ['연결하다', '어렵다', '어렵다', '좋아하다']
#
# 추출된 단어들: ['설치다', '어렵다', '만족하다']
#
# 추출된 단어들: ['좋다', '편하다', '튼튼하다', '친절하다']
#
# 추출된 단어들: ['간단하다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['간편하다']
#
# 추출된 단어들: ['빠르다', '예쁘다']
#
# 추출된 단어들: ['좋다', '친절하다', '좋다']
#
# 추출된 단어들: ['부탁드리다', '거뜬하다', '웬만하다', '안전하다', '빠르다', '저렴하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['안되다', '그렇다', '빠르다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['착하다', '착하다']
#
# 추출된 단어들: ['탁월하다', '자세하다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['착하다', '괜찮다', '멀다', '예쁘다']
#
# 추출된 단어들: ['어렵다', '많다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '튼튼하다']
#
# 추출된 단어들: ['착하다', '좋다']
#
# 추출된 단어들: ['동일하다', '좋다']
#
# 추출된 단어들: ['무겁다', '용하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['만족스럽다', '그렇다', '괜찮다']
#
# 추출된 단어들: ['동그랗다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['용하다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['없다', '예쁘다']
#
# 추출된 단어들: ['번거롭다', '정확하다', '좋다']
#
# 추출된 단어들: ['솔직하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '편리하다', '좋아하다']
#
# 추출된 단어들: ['솔직하다', '깔끔하다', '튼튼하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['간편하다', '좋다', '당연하다', '굉장하다', '만족하다']
#
# 추출된 단어들: ['속상하다']
#
# 추출된 단어들: ['살찌다', '배고프다']
#
# 추출된 단어들: ['빠르다', '예쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '만족하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['저렴하다', '좋다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['차분하다', '아니다', '예쁘다']
#
# 추출된 단어들: ['빨르다', '적당하다', '좋다', '안되다', '아쉽다', '적당하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['오래되다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['지저분하다', '깨끗하다']
#
# 추출된 단어들: ['좋다', '쉽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['무겁다', '튼튼하다']
#
# 추출된 단어들: ['튼튼하다', '편하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '빠르다', '좋다']
#
# 추출된 단어들: ['좋다', '괜찮다', '안되다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['없다', '없다', '만족스럽다']
#
# 추출된 단어들: ['이쁘다', '어렵다', '스럽다', '아니다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['만족하다', '빠르다', '이쁘다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '착하다', '좋다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['만족하다', '좋다']
#
# 추출된 단어들: ['가능하다', '유용하다']
#
# 추출된 단어들: ['만족하다', '빨르다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['간단하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['다재다능하다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['작다', '저렴하다', '저렴하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['신기하다']
#
# 추출된 단어들: ['예쁘다', '저렴하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['많다', '이쁘다']
#
# 추출된 단어들: ['많다']
#
# 추출된 단어들: ['저렴하다', '정확하다', '좋다']
#
# 추출된 단어들: ['이쁘다', '아니다', '많다', '좋다']
#
# 추출된 단어들: ['큼지막하다']
#
# 추출된 단어들: ['깔끔하다', '딱이다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '살빼다']
#
# 추출된 단어들: ['고맙다']
#
# 추출된 단어들: ['만족스럽다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['얇다', '좋다']
#
# 추출된 단어들: ['아니다', '탁하다']
#
# 추출된 단어들: ['짱짱하다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '유용하다']
#
# 추출된 단어들: ['좋다', '좋다', '무섭다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['다양하다', '좋다']
#
# 추출된 단어들: ['아니다', '좋다']
#
# 추출된 단어들: ['아니다', '아쉽다', '만족하다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['귀찮다', '다르다', '괜찮다']
#
# 추출된 단어들: ['빠르다', '이쁘다']
#
# 추출된 단어들: ['착하다', '좋다', '신기하다', '좋다', '어렵다']
#
# 추출된 단어들: ['자세하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '확실하다', '좋다', '좋다']
#
# 추출된 단어들: ['아니다']
#
# 추출된 단어들: ['빠르다', '필요하다']
#
# 추출된 단어들: ['약하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['괜찮다', '좋다']
#
# 추출된 단어들: ['이상하다', '괜찮다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['괜찮다', '없다']
#
# 추출된 단어들: ['그렇다']
#
# 추출된 단어들: ['확실하다']
#
# 추출된 단어들: ['아니다', '그렇다', '어렵다', '그렇다', '어렵다']
#
# 추출된 단어들: ['좋다', '적당하다', '이쁘다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['급하다', '괜찮다', '빠르다']
#
# 추출된 단어들: ['깔끔하다', '편하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['고급스럽다', '다양하다', '좋다']
#
# 추출된 단어들: ['나쁘다', '나쁘다', '괜찮다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: ['아니다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['꼼꼼하다', '예쁘다']
#
# 추출된 단어들: ['저렴하다', '빠르다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['시원시원하다', '좋다', '어색하다']
#
# 추출된 단어들: ['괜찮다', '편리하다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['좋다', '빠르다', '복잡하다', '좋다']
#
# 추출된 단어들: ['좋다', '좋다', '귀찮다']
#
# 추출된 단어들: ['가뿐하다', '가능하다']
#
# 추출된 단어들: ['좋다', '안되다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다', '정확하다', '많다', '좋다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: ['좋다', '다르다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['좋다', '없다']
#
# 추출된 단어들: ['아니다', '다양하다', '좋다']
#
# 추출된 단어들: ['없다', '이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['저렴하다']
#
# 추출된 단어들: ['좋다', '없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['설레다', '슬프다']
#
# 추출된 단어들: ['만족하다', '아쉽다', '좋다']
#
# 추출된 단어들: ['빠르다', '가볍다', '예쁘다', '만족하다']
#
# 추출된 단어들: ['무섭다', '살빼다']
#
# 추출된 단어들: ['솔직하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['없다', '편하다', '좋다']
#
# 추출된 단어들: ['좋다', '정확하다']
#
# 추출된 단어들: ['친절하다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['없다', '깔끔하다']
#
# 추출된 단어들: ['만족하다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['많다']
#
# 추출된 단어들: ['좋다', '좋다', '힘들다']
#
# 추출된 단어들: ['철저하다', '좋다']
#
# 추출된 단어들: ['좋다', '빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '좋다', '살빼다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['저렴하다']
#
# 추출된 단어들: ['간단하다', '편리하다']
#
# 추출된 단어들: ['좋다', '많다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['아니다', '좋다', '아프다']
#
# 추출된 단어들: ['아니다', '괜찮다']
#
# 추출된 단어들: ['이쁘다', '만족스럽다']
#
# 추출된 단어들: ['맛있다', '좋다']
#
# 추출된 단어들: ['좋다', '저렴하다']
#
# 추출된 단어들: ['좋다', '좋다', '이쁘다', '귀찮다']
#
# 추출된 단어들: ['앙증맞다', '맛있다', '만족하다']
#
# 추출된 단어들: ['좋다', '예쁘다', '좋다']
#
# 추출된 단어들: ['맛있다']
#
# 추출된 단어들: ['꼼꼼하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['새롭다', '좋다']
#
# 추출된 단어들: ['까맣다']
#
# 추출된 단어들: ['안전하다', '예쁘다', '깔끔하다', '예쁘다', '무겁다']
#
# 추출된 단어들: ['힘들다', '불편하다', '좋다', '조용하다']
#
# 추출된 단어들: ['빠르다', '만족하다']
#
# 추출된 단어들: ['좋다', '많다', '좋다']
#
# 추출된 단어들: ['좋다', '괜찮다', '편리하다', '만족하다']
#
# 추출된 단어들: ['좋다', '솔직하다', '야무지다', '좋다', '급하다', '따끈하다', '좋다', '깔끔하다', '맛있다', '괜찮다']
#
# 추출된 단어들: ['예쁘다', '편하다', '만족스럽다', '급하다', '원하다']
#
# 추출된 단어들: ['예쁘다', '근사하다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['미치다', '예쁘다']
#
# 추출된 단어들: ['귀엽다', '편리하다']
#
# 추출된 단어들: ['없다', '저렴하다', '아니다', '괜찮다', '굉장하다', '편하다', '편하다', '좋다']
#
# 추출된 단어들: ['귀찮다', '편리하다']
#
# 추출된 단어들: ['멀다', '편안하다', '좋다', '아깝다']
#
# 추출된 단어들: ['불편하다', '편하다', '좋다', '괜찮다']
#
# 추출된 단어들: ['새롭다', '좋다', '안되다', '많다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['야하다', '밉다', '밉다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['아쉽다']
#
# 추출된 단어들: ['귀찮다', '편리하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '좋다', '작다', '좋다', '좋다']
#
# 추출된 단어들: ['좋아하다']
#
# 추출된 단어들: ['좋다', '귀찮다']
#
# 추출된 단어들: ['유용하다', '좋다']
#
# 추출된 단어들: ['필요하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['없다', '조악하다', '아쉽다', '좋다', '편리하다', '좋다', '만족스럽다']
#
# 추출된 단어들: ['좋아하다']
#
# 추출된 단어들: ['좋다', '무섭다', '좋다']
#
# 추출된 단어들: ['간단하다', '좋다', '불편하다', '편리하다', '아니다', '편하다']
#
# 추출된 단어들: ['편하다', '그렇다']
#
# 추출된 단어들: ['좁다', '평평하다', '아니다', '아쉽다', '야하다', '만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편리하다', '좋다']
#
# 추출된 단어들: ['만족하다', '아니다', '없다', '확실하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '좋다', '어설프다', '밉다', '많다', '상당하다', '가능하다', '안되다', '스럽다', '아니다', '만족하다']
#
# 추출된 단어들: ['멀다', '없다', '편하다']
#
# 추출된 단어들: ['귀찮다', '좋다']
#
# 추출된 단어들: ['비싸다', '없다', '싫다', '게으르다']
#
# 추출된 단어들: ['귀찮다', '덜하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['비싸다', '편하다']
#
# 추출된 단어들: ['힘들다', '좋다']
#
# 추출된 단어들: ['설치다', '좋다']
#
# 추출된 단어들: ['좋다', '작다', '좋다', '편하다', '좋다', '만족하다']
#
# 추출된 단어들: ['많다', '딱하다', '신기하다']
#
# 추출된 단어들: ['좁다', '없다', '없다', '헷갈리다']
#
# 추출된 단어들: ['아니다', '상관없다']
#
# 추출된 단어들: ['편하다', '좋다', '좋다', '괜찮다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['새롭다', '편하다', '안되다', '약하다', '안되다', '새롭다']
#
# 추출된 단어들: ['만족스럽다']
#
# 추출된 단어들: ['피곤하다', '귀찮다', '짜증나다', '없다', '없다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['원활하다']
#
# 추출된 단어들: ['귀엽다', '편하다', '좋다']
#
# 추출된 단어들: ['멀다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['밉다', '강하다', '좋다', '비싸다', '딱하다', '없다']
#
# 추출된 단어들: ['편하다', '귀찮다']
#
# 추출된 단어들: ['귀엽다', '편하다', '좋다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['귀찮다', '아니다', '괜찮다']
#
# 추출된 단어들: ['없다', '시끄럽다', '필요하다', '유용하다', '간단하다']
#
# 추출된 단어들: ['춥다', '힘들다', '편하다']
#
# 추출된 단어들: ['귀찮다', '유용하다', '빠르다', '가능하다']
#
# 추출된 단어들: ['좋다', '편리하다', '비싸다', '부담스럽다', '아쉽다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['간편하다', '연결하다', '편리하다', '좋다']
#
# 추출된 단어들: ['만족하다', '좋다', '여전하다', '아쉽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['상관없다', '없다']
#
# 추출된 단어들: ['그렇다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['인하다', '편하다', '좋다', '가능하다', '없다', '필요하다', '아니다', '만족하다', '편하다']
#
# 추출된 단어들: ['좋다', '아쉽다']
#
# 추출된 단어들: ['아니다', '귀찮다', '만족하다', '저렴하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['비싸다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['빠르다', '편하다', '좋다']
#
# 추출된 단어들: ['오래되다', '그렇다', '힘들다']
#
# 추출된 단어들: ['좋아하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['딱이다', '편리하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편리하다', '좋다', '아쉽다']
#
# 추출된 단어들: ['다행하다', '필요하다', '힘들다', '만족하다']
#
# 추출된 단어들: ['만족하다', '밤늦다', '많다', '그렇다', '편리하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '편하다', '놀래다', '괜찮다']
#
# 추출된 단어들: ['단단하다', '원하다', '편하다', '좋다', '좋다']
#
# 추출된 단어들: ['없다', '아니다', '오래되다', '낡다', '안되다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['시끄럽다', '좋다']
#
# 추출된 단어들: ['어마어마하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['기특하다', '만족스럽다', '빨르다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['아니다', '상관없다', '많다', '예쁘다']
#
# 추출된 단어들: ['동그랗다', '아니다', '그렇다']
#
# 추출된 단어들: ['부족하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다', '새롭다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['탄탄하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['얇다', '가능하다', '오래되다', '그렇다', '아니다', '불편하다', '용하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['새롭다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '저렴하다', '만족하다']
#
# 추출된 단어들: ['새롭다', '깔끔하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '묵직하다', '정확하다', '좋다']
#
# 추출된 단어들: ['괜찮다', '좋다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '저렴하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['저렴하다', '깔끔하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['안되다', '좋다']
#
# 추출된 단어들: ['만족하다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가볍다', '예쁘다']
#
# 추출된 단어들: ['느리다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: ['아니다']
#
# 추출된 단어들: ['깔끔하다', '만족하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['필요하다', '유용하다', '예쁘다', '만족하다']
#
# 추출된 단어들: ['저렴하다', '빨르다', '없다']
#
# 추출된 단어들: ['깔끔하다', '만족하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['싫다', '깔끔하다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['멀다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가볍다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['작다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '얇다', '가볍다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['잘맞다', '튼튼하다', '좋다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['저렴하다', '깔끔하다', '만족하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['급하다', '필요하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['아니다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['다르다']
#
# 추출된 단어들: ['다르다']
#
# 추출된 단어들: ['정확하다', '튼튼하다', '이쁘다', '잘맞다', '기쁘다', '정확하다', '슬프다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['정확하다', '아니다']
#
# 추출된 단어들: ['이쁘다', '정확하다', '급하다', '아니다', '괜찮다']
#
# 추출된 단어들: ['이쁘다', '밉다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '만족스럽다']
#
# 추출된 단어들: ['깔끔하다', '얇다', '용이하다']
#
# 추출된 단어들: ['정확하다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '정확하다', '얇다', '가볍다', '좋다']
#
# 추출된 단어들: ['좋다', '저렴하다', '좋다']
#
# 추출된 단어들: ['저렴하다', '이쁘다', '아니다']
#
# 추출된 단어들: ['깔끔하다', '편리하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '빠르다', '저렴하다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['빠르다', '정확하다']
#
# 추출된 단어들: ['이쁘다', '좋다', '안되다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '쓰리다']
#
# 추출된 단어들: ['좋다', '없다', '이쁘다']
#
# 추출된 단어들: ['괜찮다', '예쁘다', '정확하다', '좋다']
#
# 추출된 단어들: ['없다', '저렴하다', '살찌다', '똑같다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '완벽하다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['나쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['좋다', '평평하다', '딱딱하다', '없다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['얇다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['느리다', '좋다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['느리다', '깔끔하다', '튼튼하다']
#
# 추출된 단어들: ['이쁘다', '정확하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다']
#
# 추출된 단어들: ['간편하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['가볍다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['엄청나다']
#
# 추출된 단어들: ['헷갈리다', '헷갈리다', '계시다', '이쁘다']
#
# 추출된 단어들: ['밉다', '좋다', '좋다', '깔끔하다', '괜찮다']
#
# 추출된 단어들: ['길다', '꼼꼼하다', '필요하다']
#
# 추출된 단어들: ['좋다', '예쁘다', '예쁘다']
#
# 추출된 단어들: ['심하다', '좋다', '만족하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['좋다', '깔끔하다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['적당하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '튼튼하다']
#
# 추출된 단어들: ['깨끗하다']
#
# 추출된 단어들: ['귀엽다', '가볍다', '좋다']
#
# 추출된 단어들: ['간단하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '귀엽다', '잘맞다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '정확하다', '좋다']
#
# 추출된 단어들: ['저렴하다', '튼튼하다', '예쁘다', '빨르다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: ['정확하다', '깔끔하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['얇다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['빠르다', '좋다', '정확하다', '부담스럽다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '느리다']
#
# 추출된 단어들: ['변하다', '이상하다', '이쁘다', '그렇다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['단단하다', '예쁘다', '예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다', '만족하다']
#
# 추출된 단어들: ['가볍다', '얇다', '이쁘다', '정확하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '편리하다', '딱좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['느리다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다']
#
# 추출된 단어들: ['만족하다', '좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['빠르다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '만족하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['없다', '만족하다']
#
# 추출된 단어들: ['가볍다', '뛰어나다']
#
# 추출된 단어들: ['없다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['얇다', '좋다', '이쁘다']
#
# 추출된 단어들: ['느리다']
#
# 추출된 단어들: ['이쁘다', '정확하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['이쁘다', '정확하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['멀다', '깔끔하다', '만족하다']
#
# 추출된 단어들: ['괜찮다', '이쁘다', '좋다']
#
# 추출된 단어들: ['튼튼하다']
#
# 추출된 단어들: ['좋다', '눈부시다']
#
# 추출된 단어들: ['편안하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['꼼꼼하다', '좋다']
#
# 추출된 단어들: ['좋다', '편리하다', '예쁘다']
#
# 추출된 단어들: ['어렵다', '안되다', '스럽다', '뛰어나다', '추하다']
#
# 추출된 단어들: ['좋다', '저렴하다', '좋다', '다양하다', '가능하다', '세련되다', '볼록하다', '좁다']
#
# 추출된 단어들: ['없다', '힘들다', '만족하다', '까다롭다']
#
# 추출된 단어들: ['좋다', '연결하다']
#
# 추출된 단어들: ['충분하다', '귀찮다', '좋다', '빠르다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '편하다', '다양하다', '설치다', '복잡하다', '없다']
#
# 추출된 단어들: ['은은하다', '완벽하다']
#
# 추출된 단어들: ['빠르다', '설레다']
#
# 추출된 단어들: ['좋다', '필요없다', '없다']
#
# 추출된 단어들: ['충분하다', '설치다', '작다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['딱좋다']
#
# 추출된 단어들: ['가능하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['친절하다', '충분하다', '좋다', '편하다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['연결하다', '충분하다']
#
# 추출된 단어들: ['부족하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['가능하다', '아쉽다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['어둡다', '새롭다', '덜하다', '넓다', '은은하다']
#
# 추출된 단어들: ['빠르다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '은은하다', '좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: ['귀찮다', '좋다']
#
# 추출된 단어들: ['저렴하다', '좋다', '작다', '덜하다', '빠르다', '좋다']
#
# 추출된 단어들: ['가볍다', '만족하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['착하다', '좋다', '없다', '아쉽다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다']
#
# 추출된 단어들: ['아니다', '은은하다']
#
# 추출된 단어들: ['괜찮다', '깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '없다']
#
# 추출된 단어들: ['좋다', '확실하다', '가볍다', '무섭다']
#
# 추출된 단어들: ['깔끔하다', '용하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['좋다', '빠르다', '정확하다']
#
# 추출된 단어들: ['착하다', '좋다', '가볍다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다', '작다', '용이하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['아쉽다']
#
# 추출된 단어들: ['좋다', '깔끔하다']
#
# 추출된 단어들: ['간편하다', '좋다']
#
# 추출된 단어들: ['불가능하다', '좋다', '불안정하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['곱다', '좋다']
#
# 추출된 단어들: ['편하다', '간단하다', '필요하다', '부담스럽다']
#
# 추출된 단어들: ['좋다', '연결하다', '아니다', '불편하다', '좋다']
#
# 추출된 단어들: ['곱다', '좋다']
#
# 추출된 단어들: ['솔직하다', '비싸다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['연결하다', '좋다']
#
# 추출된 단어들: ['아니다', '곱다', '만족스럽다']
#
# 추출된 단어들: ['많다', '궁금하다', '좋다', '없다', '좋다']
#
# 추출된 단어들: ['야하다', '간단하다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['빨르다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['만족하다', '딱이다', '연결하다', '가능하다', '좋다']
#
# 추출된 단어들: ['비싸다', '귀찮다', '비싸다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['연결하다', '그렇다']
#
# 추출된 단어들: ['유용하다', '원하다', '편하다']
#
# 추출된 단어들: ['연결하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['급하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['연결하다', '좋다', '아쉽다', '비싸다']
#
# 추출된 단어들: ['좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['연결하다']
#
# 추출된 단어들: ['똑똑하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['좋다', '답답하다', '비싸다']
#
# 추출된 단어들: ['간단하다', '깔끔하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['어렵다', '편하다', '좋다', '굳다']
#
# 추출된 단어들: ['힘들다', '동일하다', '어렵다', '멀다', '귀찮다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['높다']
#
# 추출된 단어들: ['간단하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['편리하다', '필요하다']
#
# 추출된 단어들: ['많다', '믿음직하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['좋다', '빠르다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['확실하다', '편리하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다', '가능하다', '편리하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['가능하다', '편리하다']
#
# 추출된 단어들: ['실패하다']
#
# 추출된 단어들: ['편리하다', '안되다', '편리하다', '안되다', '자유롭다', '아니다']
#
# 추출된 단어들: ['좋다', '확실하다']
#
# 추출된 단어들: ['아니다', '연결하다']
#
# 추출된 단어들: ['간편하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['편리하다']
#
# 추출된 단어들: ['좋다', '좋다', '느리다', '좋다']
#
# 추출된 단어들: ['좋다', '편리하다', '좋다']
#
# 추출된 단어들: ['편리하다', '좋다']
#
# 추출된 단어들: ['많다', '유용하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['비싸다']
#
# 추출된 단어들: ['번거롭다', '편하다']
#
# 추출된 단어들: ['간단하다', '좋다', '안되다', '아쉽다']
#
# ...
#
# 추출된 단어들: ['만족하다', '무겁다', '불편하다']
#
# 추출된 단어들: ['습하다', '친절하다', '손쉽다', '연결하다', '없다', '만족하다']
#
# 추출된 단어들: ['좋다', '습하다']
#
# 추출된 단어들: ['습하다', '강력하다', '뽀송하다', '원하다', '없다']
#
# 추출된 단어들: ['습하다', '아니다', '그렇다', '만족하다', '가능하다', '중요하다', '안되다', '좋다', '좋다', '민감하다', '괜찮다', '추하다']
#
# 추출된 단어들: ['습하다', '춥다', '건조하다', '이쁘다', '좋다', '좋다', '가능하다', '편하다']
#
# 추출된 단어들: ['좋다', '연결하다', '편하다', '귀찮다', '번거롭다', '편하다', '편하다', '좋다', '넉넉하다', '쓰리다']
#
# 추출된 단어들: ['좋다', '만족스럽다', '간편하다', '편하다']
#
# 추출된 단어들: ['쾌적하다', '예쁘다']
#
# 추출된 단어들: ['깔끔하다', '편리하다', '반갑다', '만족하다']
#
# 추출된 단어들: ['좋다', '괜찮다', '습하다', '눅눅하다', '아니다', '좋다', '좋다']
#
# 추출된 단어들: ['만족스럽다', '좋다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다', '빠르다', '유용하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['심하다', '습하다', '습하다', '축축하다', '안되다', '습하다', '괜찮다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['작다', '새롭다', '작다', '불편하다', '좋다']
#
# 추출된 단어들: ['번거롭다', '편하다', '시원하다', '시원하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['엄청나다', '급하다', '급하다', '좋다', '빠르다', '깔끔하다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['신기하다', '필요하다', '작다', '바쁘다', '낮다', '찝찝하다', '아깝다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['시원시원하다', '안되다', '없다']
#
# 추출된 단어들: ['없다', '편하다', '편하다', '똑똑하다', '편하다']
#
# 추출된 단어들: ['좋다', '축축하다', '뽀송하다']
#
# 추출된 단어들: ['마르다', '힘들다', '급하다', '간편하다', '좋다', '쾌적하다', '보송보송하다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['좋다', '편리하다', '편리하다', '좋다']
#
# 추출된 단어들: ['쾌적하다', '다르다', '예쁘다', '필요없다', '좋다', '편하다']
#
# 추출된 단어들: ['눅눅하다', '좋다', '편하다', '안전하다', '가능하다']
#
# 추출된 단어들: ['없다', '편리하다']
#
# 추출된 단어들: ['안전하다', '빠르다', '이쁘다', '좋다', '편하다', '간편하다', '좋다']
#
# 추출된 단어들: ['작다', '그렇다', '깔끔하다', '가능하다', '편하다']
#
# 추출된 단어들: ['많다', '뻔하다', '확실하다', '습하다', '덥다', '꼼꼼하다', '만족스럽다']
#
# 추출된 단어들: ['눅눅하다', '싫다', '필요하다', '야하다', '없다', '좋다', '가능하다', '좋다', '습하다']
#
# 추출된 단어들: ['습하다', '덥다', '확실하다', '마르다']
#
# 추출된 단어들: ['없다', '없다', '좋다', '간편하다', '깔끔하다']
#
# 추출된 단어들: ['좋다', '습하다', '안되다', '뽀송하다', '행복하다']
#
# 추출된 단어들: ['습하다', '필요하다', '연결하다', '좋다', '간편하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '딱좋다', '편하다', '가능하다', '넉넉하다', '편하다', '좋다', '덥다', '습하다', '유용하다']
#
# 추출된 단어들: ['좋다', '가능하다', '편하다', '뽀송하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['이쁘다', '이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['다양하다', '좋다']
#
# 추출된 단어들: ['신기하다', '다양하다']
#
# 추출된 단어들: ['없다', '이쁘다', '만족하다']
#
# 추출된 단어들: ['편안하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '이쁘다']
#
# 추출된 단어들: ['은은하다', '좋다']
#
# 추출된 단어들: ['불편하다']
#
# 추출된 단어들: ['좋다', '사악하다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['비싸다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['비싸다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['괜찮다', '이쁘다', '추하다']
#
# 추출된 단어들: ['안되다', '만족하다']
#
# 추출된 단어들: ['가능하다', '편리하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['빨르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['어렵다', '편리하다']
#
# 추출된 단어들: ['적당하다', '딱이다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가볍다', '예쁘다']
#
# 추출된 단어들: ['없다', '정확하다', '깔끔하다']
#
# 추출된 단어들: ['적당하다', '정확하다', '좋다']
#
# 추출된 단어들: ['정확하다', '깔끔하다', '이쁘다']
#
# 추출된 단어들: ['적당하다', '깔끔하다', '괜찮다']
#
# 추출된 단어들: ['튼튼하다', '정확하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['괜찮다', '빠르다', '이쁘다']
#
# 추출된 단어들: ['이쁘다', '작다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['빠르다', '좋다', '아니다']
#
# 추출된 단어들: ['예쁘다', '낮다']
#
# 추출된 단어들: ['예쁘다', '빨르다', '야하다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['깨끗하다', '좋다', '없다']
#
# 추출된 단어들: ['정확하다', '좋다', '일정하다', '괜찮다']
#
# 추출된 단어들: ['이쁘다', '좋다', '좋다']
#
# 추출된 단어들: ['빠르다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '튼튼하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['가볍다', '이쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['스럽다']
#
# 추출된 단어들: ['없다', '없다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '좋다', '멀쩡하다']
#
# 추출된 단어들: ['아쉽다', '예쁘다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['새롭다']
#
# 추출된 단어들: ['좋다', '빠르다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '단순하다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다', '완벽하다']
#
# 추출된 단어들: ['간결하다', '이쁘다', '빨르다']
#
# 추출된 단어들: ['유용하다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '만족하다']
#
# 추출된 단어들: ['깔끔하다', '튼튼하다', '저렴하다', '만족하다']
#
# 추출된 단어들: ['깔끔하다', '정확하다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '빨르다']
#
# 추출된 단어들: ['좋다', '저렴하다', '좋다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다', '깔끔하다', '가볍다', '좋다']
#
# 추출된 단어들: ['예쁘다', '시원시원하다', '빨르다', '저렴하다']
#
# 추출된 단어들: ['좋다', '빨르다']
#
# 추출된 단어들: ['이쁘다', '만족하다']
#
# 추출된 단어들: ['적당하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '가볍다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다']
#
# 추출된 단어들: ['필요없다', '깔끔하다', '튼튼하다']
#
# 추출된 단어들: ['이쁘다', '빠르다', '좋다', '좋다', '정확하다']
#
# 추출된 단어들: ['깔끔하다', '얇다', '좋다']
#
# 추출된 단어들: ['좋다', '예쁘다', '살빼다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['안되다']
#
# 추출된 단어들: ['귀찮다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['만족하다', '아쉽다', '없다']
#
# 추출된 단어들: ['뿌듯하다']
#
# 추출된 단어들: ['비싸다', '힘들다', '편하다', '좋다', '좋아하다']
#
# 추출된 단어들: ['좋다', '좋아하다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '심하다', '간단하다']
#
# 추출된 단어들: ['기대하다', '아니다', '심하다', '덜하다', '스럽다', '없다', '편하다', '좋다', '어렵다']
#
# 추출된 단어들: ['이쁘다', '만족스럽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '꼼꼼하다']
#
# 추출된 단어들: ['편하다', '좋다', '편하다']
#
# 추출된 단어들: ['편하다', '좋다', '이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['쉽다', '설치다', '깔끔하다']
#
# 추출된 단어들: ['완벽하다']
#
# 추출된 단어들: ['튼튼하다', '좋다', '친절하다', '좋다']
#
# 추출된 단어들: ['힘들다', '원하다', '힘들다']
#
# 추출된 단어들: ['좋다', '편하다', '좋다']
#
# 추출된 단어들: ['꼼꼼하다', '좋다', '안되다', '비싸다', '좋다', '좋다']
#
# 추출된 단어들: ['친절하다', '바쁘다', '빠르다', '빠르다', '덥다', '건강하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['어렵다', '필요하다', '편하다', '좋다']
#
# 추출된 단어들: ['어렵다', '만족스럽다']
#
# 추출된 단어들: ['쉽다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['없다', '충분하다', '부드럽다']
#
# 추출된 단어들: ['친절하다', '안되다', '친절하다', '원하다', '저렴하다', '아니다', '저렴하다', '편하다', '필요하다', '번하다']
#
# 추출된 단어들: ['불편하다', '친절하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '깨끗하다', '용하다']
#
# 추출된 단어들: ['괜찮다', '좋다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '동일하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['흐뭇하다']
#
# 추출된 단어들: ['피곤하다', '편리하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '편리하다']
#
# 추출된 단어들: ['비싸다', '가능하다', '신기하다', '신나다']
#
# 추출된 단어들: ['편하다', '편하다', '좋다']
#
# 추출된 단어들: ['편하다', '길다']
#
# 추출된 단어들: ['신기하다', '편하다']
#
# 추출된 단어들: ['편하다', '좋다', '약하다', '불안하다']
#
# 추출된 단어들: ['간편하다', '작다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편리하다', '번거롭다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '헐겁다']
#
# 추출된 단어들: ['나쁘다', '좋다', '많다', '좋다']
#
# 추출된 단어들: ['가능하다', '안좋다', '좋다']
#
# 추출된 단어들: ['빡치다', '좋다', '약하다', '아쉽다', '까다롭다', '무섭다', '좋다']
#
# 추출된 단어들: ['멀다', '아쉽다', '좋다']
#
# 추출된 단어들: ['귀엽다', '신기하다']
#
# 추출된 단어들: ['필요하다']
#
# 추출된 단어들: ['딱이다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['쉽다', '가능하다', '필요하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['멀다', '좋다']
#
# 추출된 단어들: ['약하다', '안되다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '좋다', '좋다', '추하다']
#
# 추출된 단어들: ['좁다']
#
# 추출된 단어들: ['훌륭하다', '간단하다', '편리하다']
#
# 추출된 단어들: ['좋다', '용하다', '없다']
#
# 추출된 단어들: ['불안하다', '멀다', '편하다', '좋다']
#
# 추출된 단어들: ['오래되다', '그렇다', '힘들다', '편하다', '만족하다']
#
# 추출된 단어들: ['귀찮다', '필요하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀찮다', '비싸다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['없다', '괜찮다', '아쉽다']
#
# 추출된 단어들: ['좋다', '미치다', '편하다']
#
# 추출된 단어들: ['짧다', '아니다']
#
# 추출된 단어들: ['만족하다', '사소하다', '확실하다']
#
# 추출된 단어들: ['편하다', '안되다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['비싸다', '신기하다', '귀엽다']
#
# 추출된 단어들: ['적당하다', '좋다', '만족스럽다', '좋다']
#
# 추출된 단어들: ['좁다', '짱짱하다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['편하다', '비싸다']
#
# 추출된 단어들: ['빠르다', '없다', '편리하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['귀찮다', '만족하다', '좋다', '힘드다', '이쁘다', '좋다', '만족스럽다']
#
# 추출된 단어들: ['편리하다', '좋다', '만족하다']
#
# 추출된 단어들: ['유용하다', '편하다']
#
# 추출된 단어들: ['좋다', '부족하다', '안되다', '불편하다']
#
# 추출된 단어들: ['빠르다', '편하다']
#
# 추출된 단어들: ['안좋다']
#
# 추출된 단어들: ['좋다', '없다', '귀찮다']
#
# 추출된 단어들: ['없다', '좋다']
#
# 추출된 단어들: ['비싸다', '만족하다']
#
# 추출된 단어들: ['굳다', '굳다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['귀찮다', '짜증나다']
#
# 추출된 단어들: ['작다', '정확하다', '저렴하다', '만족하다', '안되다', '깔끔하다']
#
# 추출된 단어들: ['작다', '좋다', '좋다', '예쁘다']
#
# 추출된 단어들: ['착하다', '좋다', '좋다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '빨르다', '저렴하다']
#
# 추출된 단어들: ['작다']
#
# 추출된 단어들: ['작다', '저렴하다', '좋다']
#
# 추출된 단어들: ['작다', '애매하다']
#
# 추출된 단어들: ['작다', '없다', '정확하다']
#
# 추출된 단어들: ['좁다', '좋다']
#
# 추출된 단어들: ['여전하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['저렴하다', '튼튼하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['딱하다', '정확하다']
#
# 추출된 단어들: ['좋다', '귀찮다']
#
# 추출된 단어들: ['좋다', '저렴하다', '만족스럽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['정확하다', '가볍다', '좋다']
#
# 추출된 단어들: ['좋다', '없다', '좋다']
#
# 추출된 단어들: ['필요하다', '간편하다', '좋다']
#
# 추출된 단어들: ['솔직하다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '가볍다', '좋다']
#
# 추출된 단어들: ['놀래다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: ['저렴하다', '가능하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['가볍다', '이쁘다', '착하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['이쁘다', '깔끔하다']
#
# 추출된 단어들: ['싫다', '좋다']
#
# 추출된 단어들: ['싫다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '작다']
#
# 추출된 단어들: ['정확하다', '연결하다']
#
# 추출된 단어들: ['편하다', '빠르다']
#
# 추출된 단어들: ['예쁘다', '좋다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: ['느리다']
#
# 추출된 단어들: ['작다', '좋아하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: ['안되다', '쓰리다', '무지하다', '차갑다']
#
# 추출된 단어들: ['착하다', '좋다', '많다', '좋다', '비싸다', '저렴하다']
#
# 추출된 단어들: ['예쁘다', '좋다', '서툴다', '다르다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['좋다', '예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['튼튼하다', '좋다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['저렴하다', '가능하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['만족스럽다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['용하다', '좋다', '깔끔하다']
#
# 추출된 단어들: ['가능하다', '편하다', '좋다']
#
# 추출된 단어들: ['가능하다', '좋다']
#
# 추출된 단어들: ['편리하다', '좋다', '예쁘다']
#
# 추출된 단어들: ['기대하다', '없다', '깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['얇다', '좋다', '튼튼하다', '없다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['필요하다', '가능하다', '착하다', '만족하다']
#
# 추출된 단어들: ['필요하다', '약하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['덥다', '용하다', '괜찮다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '가볍다', '좋다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['견고하다', '좋다']
#
# 추출된 단어들: ['정확하다', '좋다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '살빼다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['필요하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['안되다', '정확하다', '좋다', '만족하다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '이쁘다']
#
# 추출된 단어들: ['편하다', '예쁘다']
#
# 추출된 단어들: ['작다', '가볍다', '정확하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['예쁘다', '저렴하다']
#
# 추출된 단어들: ['깔끔하다', '저렴하다']
#
# 추출된 단어들: ['적당하다', '깔끔하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['나쁘다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['두껍다', '아니다', '만족스럽다', '정확하다', '정확하다']
#
# 추출된 단어들: ['아니다', '좋다']
#
# 추출된 단어들: ['빠르다', '깔끔하다', '미세하다', '다르다', '한결같다', '좋다']
#
# 추출된 단어들: ['가볍다', '좋다', '튼튼하다', '좋다', '좋다', '이쁘다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '빠르다', '편하다', '가능하다', '저렴하다']
#
# 추출된 단어들: ['만족스럽다', '자세하다', '자세하다', '야하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['연결하다', '자세하다', '많다', '유용하다']
#
# 추출된 단어들: ['정확하다', '이쁘다', '유용하다']
#
# 추출된 단어들: ['자세하다', '좋다', '좋다']
#
# 추출된 단어들: ['검다', '번거롭다']
#
# 추출된 단어들: ['필요하다', '깔끔하다']
#
# 추출된 단어들: ['굉장하다']
#
# 추출된 단어들: ['좋다', '좋다']
#
# 추출된 단어들: ['아니다']
#
# 추출된 단어들: ['깔끔하다', '정확하다']
#
# 추출된 단어들: ['만족하다', '이쁘다', '자세하다']
#
# 추출된 단어들: ['정확하다', '적당하다', '괜찮다', '저렴하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['급하다', '빨르다']
#
# 추출된 단어들: ['많다', '불편하다', '튼튼하다', '좋다', '단순하다', '용하다', '좋다']
#
# 추출된 단어들: ['약하다']
#
# 추출된 단어들: ['높다', '얇다', '편하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['재밌다']
#
# 추출된 단어들: ['깔끔하다', '없다']
#
# 추출된 단어들: ['좋다', '부족하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['예쁘다', '깔끔하다', '평평하다', '정확하다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: ['좋다', '없다', '꾸준하다', '간단하다', '만족스럽다']
#
# 추출된 단어들: ['적당하다', '정확하다']
#
# 추출된 단어들: ['깔끔하다', '없다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: []
#
# 추출된 단어들: ['이쁘다', '세련되다']
#
# 추출된 단어들: ['벅차다', '빠르다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['튼튼하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['깔끔하다', '착하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['좋다', '저렴하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['빠르다', '좋다', '가능하다', '좋다']
#
# 추출된 단어들: ['완벽하다', '정확하다', '기대하다', '안되다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['정확하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['완벽하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['정확하다', '완벽하다']
#
# 추출된 단어들: ['빠르다']
#
# 추출된 단어들: ['깔끔하다', '이쁘다', '연결하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좋다', '미묘하다', '정확하다', '가볍다', '동일하다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '아쉽다']
#
# 추출된 단어들: ['예쁘다', '깔끔하다', '정확하다', '변하다', '그렇다']
#
# 추출된 단어들: ['깔끔하다', '동일하다', '건강하다']
#
# 추출된 단어들: ['깔끔하다', '좋다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['깔끔하다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빨르다', '작다', '용이하다']
#
# 추출된 단어들: ['빠르다', '편리하다']
#
# 추출된 단어들: ['편하다']
#
# 추출된 단어들: ['좋다', '깔끔하다']
#
# 추출된 단어들: ['좋다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['연결하다', '좋다']
#
# 추출된 단어들: ['정확하다', '가볍다', '좋다']
#
# 추출된 단어들: ['괜찮다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['저렴하다', '좋다']
#
# 추출된 단어들: ['착하다', '귀엽다', '가능하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['가능하다', '편하다', '아니다', '많다', '좋다', '빨르다']
#
# 추출된 단어들: ['빠르다', '깔끔하다', '이쁘다', '괜찮다']
#
# 추출된 단어들: ['자세하다', '좋다', '저렴하다']
#
# 추출된 단어들: ['재밌다', '빠르다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: ['예쁘다', '야무지다']
#
# 추출된 단어들: ['이쁘다', '괜찮다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: ['이쁘다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '작다', '좋다']
#
# 추출된 단어들: ['없다', '좋다', '견고하다', '아니다', '신기하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['정확하다', '슬프다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['정확하다', '필요하다', '간편하다', '좋다', '꼼꼼하다', '깔끔하다', '깔끔하다', '편안하다', '신기하다', '다양하다', '간편하다', '가능하다', '좋다', '간편하다']
#
# 추출된 단어들: ['인하다', '정확하다', '필요하다', '굉장하다', '많다', '만족스럽다', '얇다', '가볍다', '깔끔하다', '예쁘다', '얇다', '튼튼하다', '또렷하다', '선명하다', '필요없다', '가능하다', '편리하다', '좋다', '간편하다', '정확하다', '좋다', '좋다', '좋다', '유용하다', '만족하다']
#
# 추출된 단어들: ['없다', '간편하다', '좋다', '아니다', '가능하다', '확실하다', '좋아하다', '간단하다', '아니다', '깔끔하다', '좋다', '굳다']
#
# 추출된 단어들: ['인하다', '없다', '답답하다', '좋다', '없다', '든든하다', '작다', '어렵다', '큼지막하다', '좋다', '가능하다', '어렵다', '좋다', '필요없다', '많다', '좋다', '딱이다', '이쁘다', '고급스럽다', '낮다', '좋다', '좋다', '번거롭다', '편리하다', '가능하다', '좋다', '좋다', '굉장하다', '만족스럽다', '좋다', '건강하다', '성공하다', '좋다']
#
# 추출된 단어들: ['다양하다', '민망하다', '똑같다', '아니다', '그렇다', '좋다', '좋다', '많다', '좋다', '가볍다', '굉장하다', '고급스럽다', '편하다', '좋다', '쉽다', '편하다']
#
# 추출된 단어들: ['다양하다', '좋다', '빠르다']
#
# 추출된 단어들: ['이쁘다', '복잡하다']
#
# 추출된 단어들: ['괜찮다', '그렇다', '없다', '정확하다', '많다', '그렇다']
#
# 추출된 단어들: ['좋다', '필요하다']
#
# 추출된 단어들: ['만족하다']
#
# 추출된 단어들: ['없다', '가능하다']
#
# 추출된 단어들: ['훌륭하다', '이쁘다']
#
# 추출된 단어들: ['편리하다', '맑다', '아니다', '좋다']
#
# 추출된 단어들: ['이쁘다', '신기하다', '좋다', '좋다']
#
# 추출된 단어들: ['아니다', '아니다', '만족하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['좁다', '적당하다', '만족하다', '작다']
#
# 추출된 단어들: ['딱하다', '없다', '좋다', '좋다']
#
# 추출된 단어들: ['편하다', '좋다']
#
# 추출된 단어들: ['이쁘다', '딱이다']
#
# 추출된 단어들: ['강하다']
#
# 추출된 단어들: ['이쁘다', '괜찮다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['적당하다', '편하다']
#
# 추출된 단어들: ['좋다', '편하다']
#
# 추출된 단어들: ['빠르다', '깔끔하다', '튼튼하다', '좋다', '아니다', '적당하다', '나쁘다', '아쉽다', '없다', '아쉽다']
#
# 추출된 단어들: ['예쁘다', '뿌듯하다', '작다', '깨끗하다', '없다', '아쉽다']
#
# 추출된 단어들: ['좋다', '없다', '왠만하다']
#
# 추출된 단어들: ['조용하다']
#
# 추출된 단어들: ['귀엽다']
#
# 추출된 단어들: ['좋다', '작다']
#
# 추출된 단어들: ['조그맣다', '편하다', '가볍다', '편하다', '시끄럽다', '좋다']
#
# 추출된 단어들: ['작다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['아쉽다', '편하다', '좋다']
#
# 추출된 단어들: ['좋다', '필요하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['새롭다', '좋다']
#
# 추출된 단어들: ['오래되다', '좋다']
#
# 추출된 단어들: ['오래되다', '좋다', '불편하다', '편하다', '좋다', '만족하다', '정확하다', '정확하다']
#
# 추출된 단어들: ['신속하다', '빠르다', '깔끔하다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['그렇다', '필요하다', '만족하다']
#
# 추출된 단어들: ['많다']
#
# 추출된 단어들: ['좋다', '좋다', '만족하다']
#
# 추출된 단어들: ['예쁘다', '가능하다']
#
# 추출된 단어들: ['깔끔하다', '좋다']
#
# 추출된 단어들: ['이쁘다', '편하다']
#
# 추출된 단어들: ['좋다', '저렴하다']
#
# 추출된 단어들: ['급하다', '괜찮다', '좋다', '소중하다']
#
# 추출된 단어들: ['빠르다', '좋다']
#
# 추출된 단어들: ['새롭다', '새롭다', '이쁘다', '맛있다']
#
# 추출된 단어들: ['맛있다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['맛있다', '편리하다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['이쁘다', '좋다', '아니다', '불편하다']
#
# 추출된 단어들: ['저렴하다', '빠르다', '좋다', '만족하다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['빠르다', '이쁘다', '좋다']
#
# 추출된 단어들: ['아니다', '이쁘다', '좋다']
#
# 추출된 단어들: []
#
# 추출된 단어들: ['깔끔하다', '예쁘다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['이쁘다', '용하다', '편리하다', '정확하다', '만족하다']
#
# 추출된 단어들: ['좋다', '좋다', '빠르다']
#
# 추출된 단어들: ['좋다', '깔끔하다', '따뜻하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '좋다']
#
# 추출된 단어들: ['좋다', '많다', '좋다']
#
# 추출된 단어들: ['충분하다', '가능하다', '좋다']
#
# 추출된 단어들: ['예쁘다', '깔끔하다', '좋다', '없다']
#
# 추출된 단어들: ['예쁘다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['이쁘다', '좋다']
#
# 추출된 단어들: ['풍부하다', '좋다', '은은하다']
#
# 추출된 단어들: ['없다', '좋다', '좋다', '깔끔하다', '예쁘다', '좋다', '조용하다', '연결하다', '편하다']
#
# 추출된 단어들: ['편하다', '예쁘다', '만족하다']
#
# 추출된 단어들: ['예쁘다', '예쁘다', '만족하다']
#
# 추출된 단어들: ['좋다', '편리하다', '좋다']
#
# 추출된 단어들: ['이쁘다', '없다', '연결하다']
#
# 추출된 단어들: ['건조하다', '힘들다', '만족하다', '좋다', '편리하다', '좋다']
#
# 추출된 단어들: ['급하다', '예쁘다', '편하다', '예쁘다', '좋다']
#
# 추출된 단어들: ['좋다']
#
# 추출된 단어들: ['무겁다', '좋다', '깔끔하다']
#
# 추출된 단어들: ['빠르다', '좋다']

# %%
from wordcloud import WordCloud
from collections import Counter
import matplotlib.pyplot as plt

# %%
count_list = []

for words in extracted_words_list:
    count = Counter(words)
    count.most_common(100)
    count_list.append(count)

# %%
# 모든 Conter 객체를 합치기
total_counter = Counter()
for counter in count_list:
    total_counter += counter

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\Windows\Fonts\H2GTRE.TTF',
                     width = 700,
                     height = 700,
                     background_color = 'white',
                     colormap = 'spring',
                     random_state = 1).generate_from_frequencies(total_counter)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('word cloud', size=13)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### 부정리뷰

# %%
neg_df
# Out:
#                작성자        작성날짜   별점  \
# 21           하니614  2024.07.03  2.5
# 90           어디든곶감  2024.02.15  2.3
# 140            던덩구  2024.03.28  2.5
# 147             수먕  2022.08.22  2.0
# 149         221124  2023.04.12  1.0
# 152     robbieshaw  2021.11.09  2.5
# 180    jwhsgsuhdjw  2023.10.24  1.0
# 197        anny333  2023.01.22  2.5
# 230           마이주문  2024.02.07  2.0
# 445         soom26  2024.02.08  2.5
# 470          도도349  2021.09.04  2.0
# 486     lr10****62  2023.05.04  2.5
# 488         SPNV74  2021.09.14  1.0
# 775          피에스와2  2024.02.14  1.0
# 1343         라에다엄마  2020.03.11  2.5
# 1344           스벅빠  2019.12.12  2.3
# 1345          성우90  2020.05.04  1.0
# 1758          채준원3  2022.02.15  2.5
# 1880         채움366  2022.03.16  1.0
# 1905         미니언즈v  2021.09.19  1.0
# 1906      KIM_DDYO  2022.01.22  1.5
# 1948   박소현(sophie)  2022.07.20  2.5
# 2345        박다원777  2024.05.19  2.5
# 2597          키미태다  2022.08.19  2.0
# 2603       lunara_  2024.03.05  1.0
# 2634           원유군  2023.12.06  1.0
# 2640           얌냠♡  2023.12.01  2.3
# 2717        mm3492  2024.02.17  2.0
# 2855          000주  2023.07.18  1.0
# 3448         snoh3  2022.08.31  1.0
# 3473            마뱁  2022.10.01  2.5
# 3476         경모아이디  2022.08.20  2.0
# 3486         지뇽스러움  2022.11.09  2.5
# 3793  hyojiniiiiii  2024.01.05  1.0
#
#                                                      내용
# 21    앱 연동이 되니까 너무 편 하 고 좋더라고요 근데 앱들어가서 버튼을 터치하기까지 렉...
# 90    스위치가 냉장고 옆쪽에 있어 스마트 스위치를 구매했지만 냉장고에 가려진거 때문인지 ...
# 140                            리모콘을 같이 셋트로 하면 좋았을 듯 합니다
# 147   계속 안붙고 떨어져서 끈끈이를 샀지만 뭐가 문제인지 붙이면 불이 켜지질않음 걍 난 ...
# 149   뭘 어떻게 만든건지 브라캣 다떨어지고 난리납니다 돈주고 쓰레기를 샀어요 사지마세요 ...
# 152   생각보다 소리가 너무 커서 안좋아요, 내구성도 약해서 몇달이면 고장 날듯해요. 5만...
# 180   진짜 별로예요 이게 와이파이로 연결해서 쓰는건데 허구언날 무한로딩에 연결이 안될 때...
# 197   핸드폰 연동해서 쓰는건데.......아침에 쓰고 저녁에 쓰려면 서비스연결이 안됩답니...
# 230   간편하고 설정쉬워서 좋은데 쓰다보니까 바닥에 탁탁쳐집니다 고장나겠어요 한쪽발 뛸때마...
# 445   1년 전에 구매하고 괜찮았어서 친정에 두려고 이번에 하나를 더 구매했는데, 두 기기...
# 470   이 제품은 제품보다도 어플이 정말 별로예요. 제품도 처음 받아서 설치해보고 생각보다...
# 486   일단 배송 평균 2~3일 앞면 필름있는줄암..없음 기스 대박 걍쓸사람만^^ 양면 테...
# 488   어플로 끄고 켜야하는데 어플이 툭하면 먹통이고 예약해놔도 어플이 먹통이라 안 켜지기...
# 775   구입한지 육개월 만에 건전지가 빨리 닳기 시작하더니 일년도 되기전에 새 건전지 교체...
# 1343  설정안하고 그냥 무게만 재고 싶은데 자꾸 P0이 뜨면서 설정해야만 무게를 잴수잇음....
# 1344           편평한곳에 두어도 지 맘대로 몸무게 측정 하네요. 그냥 환불 부탁드립니다
# 1345                              없어요.no good .......ㅠㅠ
# 1758  오스람 저가제품에 비해 소음도 없고 리모컨도 블루투스방식이라 편리하고 좋으나 프로라...
# 1880  등록이 매우어렵습니다.등록과정이 어려운게 아니라 기기자체가 인식율이 매우 저조합니다...
# 1905  정말 별로네요처음엔 좋은줄 알고 쓰다가어플 서버가 너무 불안정하고어플 자체 복구 들...
# 1906  연결도 자주끊기고 어플오류도 잦아요. 어플에 등록문제시 해결방법이 쉽게 정리안되어 ...
# 1948  지난 3월 봄에 구입한 것인데요. 얼마 안 쓰니 몸무게가 이상하게 나옵니다. 지금도...
# 2345  연동도  안되고  설명서대로 몇번이나 반복하나  포기했네요   기대한만큼 실망이 큽...
# 2597  저기요.. 그냥 리모컨이랑 함께 파세요.. 그거 어떻게라도 가격으로 한명이라도 낚아...
# 2603                              안 돼요. 사지마세요. 다 댓글알바인가
# 2634                       설치후 앱연동안됨유튜브에서나온대로 해도 불가돈만버림
# 2640                  누르는 힘을 강으로 했는데도 너무 약해서 불켜고 끄는게 안됨
# 2717  진짜 맘같아서는 환불각인데 상자가 없어서 그냥 쓰는 제품….. 다른 분들은 잘 쓰는...
# 2855  기존 체중계 고장나서 새로 샀어요. 근데 신체나이 +29살 차이 나네요? 55살 머...
# 3448  상자에 음성인식 된다고 나와 있지만…정작 구글홈과 사용하려면 미니허브를 별도로 구매...
# 3473                     누르는 힘이 생각보다 약해서 아쉽네요ㅠㅠ 무용지물입니다
# 3476            가격은 좀 비싸지만 아주 만족합니다. 역방향으로도 할 수 있어서 좋아요
# 3486  배송 지연되어서 왔어요사실 오늘의집에서 구매한 물건들 중 80%는 배송지연이라 별로...
# 3793  소리가 너무 커요 가습기에서 자꾸 소리가 나고 불끄고 자다가도 쿵쿵 소리나서 놀랜적...

# %%
cleaned_contents_list = []

for content in neg_df['내용']:
    # 공백 및 줄바꿈 제거
    cleaned_content = content.strip()  # 양쪽 공백 제거
    
    # 연속된 공백을 단일 공백으로 변환
    cleaned_content = ' '.join(cleaned_content.split())
    
    cleaned_contents_list.append(cleaned_content)

# %%
#추출된 단어들을 저장할 리스트
extracted_words_list = []

# cleaned_contents_list에 있는 각 텍스트에 대해 okt_pos_tagging 함수 호출하여 추출된 단어들 리스트에 저장
for text in cleaned_contents_list:
    extracted_words = okt_pos_tagging(text)
    extracted_words_list.append(extracted_words)

# 저장된 추출된 단어들 리스트 출력
for idx, extracted_words in enumerate(extracted_words_list, start=1):
    print(f'추출된 단어들: {extracted_words}')
    print()
# Out:
# 추출된 단어들: ['앱', '연동', '편', '고', '좋다', '앱', '버튼', '터치', '렉', '경우', '불편하다', '타이머', '설정', '점', '편하다', '거', '사용', '후', '진짜', '삶', '질', '수직', '상승']
#
# 추출된 단어들: ['스위치', '냉장고', '옆쪽', '스마트', '스위치', '구매', '냉장고', '때문', '미터', '거리', '리모컨', '작동', '안함']
#
# 추출된 단어들: ['리모콘', '셋트', '좋다', '듯']
#
# 추출된 단어들: ['계속', '끈끈이', '뭐', '문제', '붙이', '불', '난', '비싸다', '쓰레기', '개별', '마켓']
#
# 추출된 단어들: ['뭘', '브라', '캣', '난리', '돈', '쓰레기', '사지', '계속', '온', '집안', '부수']
#
# 추출된 단어들: ['생각', '소리', '커서', '안좋다', '구성', '약하다', '달이', '고장', '해', '사용', '모터', '안좋다', '거', '꼭', '서보모터', '소리', '기어', '플라스틱', '메탈', '사용', '지저분하다', '소리', '안나', '생각', '가격', '대비', '실제', '값', '만원']
#
# 추출된 단어들: ['진짜', '별로', '와이파이', '연결하다', '허구', '날', '무한', '로딩', '연결', '안되다', '많다']
#
# 추출된 단어들: ['핸드폰', '연동', '아침', '저녁', '서비스', '연결', '안되다', '다시', '연결', '그게', '복잡하다', '리모컨', '가격', '사악하다', '사용', '불편', '짜증', '뽀', '저렴', '다시', '상술', '당하다', '요', '당하다']
#
# 추출된 단어들: ['간편하다', '설정', '쉽다', '좋다', '보', '바닥', '탁탁', '고장', '한쪽', '발', '탁탁', '미치다', '스트레스']
#
# 추출된 단어들: ['전', '구매', '괜찮다', '친정', '려고', '더', '구매', '두', '기기', '측정값', '다르다', '아침', '저녁', '테스트', '많다', '차이', '과정', '영상', '오차', '측정', '그렇다', '아니다', '주식', '오락가락', '숫자', '놀음', '예민하다', '로서', '실망']
#
# 추출된 단어들: ['제품', '제품', '어플', '정말', '별로', '제품', '처음', '설치', '생각', '정말', '스툭튀', '작동', '모터', '제품', '단가', '때문', '굉장하다', '저렴하다', '걸', '소리', '꽤', '커서', '집', '강아지', '어플', '제일', '별로', '어플', '스위치', '오프', '버튼', '눌', '리지', '스위치', '핸드폰', '연동', '그냥', '일어나서', '불', '정도', '어플', '예약', '작동', '기능', '제대로', '작동', '스위치', '버튼', '절대', '눌리질', '안눌려', '예약', '설정', '그것', '작동', '스위치', '버튼', '안눌리', '그냥', '어플', '문제', '어플', '개선', '사항', '많다', '거', '구글', '플레이스토어', '똑같다', '소리', '계시다', '개선', '안되다', '최근', '리뷰', '답변', '없다', '거', '개선', '예정', '없다', '건가', '그렇다', '기본', '기능', '작동', '어렵다', '스마트', '제품', '참고', '플레이스토어', '리뷰', '답변', '소프트웨어', '업데이트', '확인', '다', '권한', '설정', '확인', '기기', '도', '확인', '동일하다']
#
# 추출된 단어들: ['배송', '평균', '앞', '필름', '암', '없다', '기스', '대박', '사람', '양면', '테입', '개', '쿠판으류', '몬스터', '실리콘', '테', '츠', '보조', '규정', '함', '어플', '사용', '지금', '괜찮다', '중', '양면', '개론', '절대', '안되다', '시공', '드릴', '드라이버', '날', '까맣다', '임', '퇴근', '바닥', '사용', '안되다', '돈']
#
# 추출된 단어들: ['어플', '어플', '툭하면', '먹통', '예약', '어플', '먹통', '안', '일수', '짜증나다', '돈', '제대로', '못']
#
# 추출된 단어들: ['구입', '한지', '육개', '건전지', '시작', '년도', '기전', '새', '건전지', '교체', '일주일', '계속', '건전지', '교체', '교체', '젠', '건전지', '하마']
#
# 추출된 단어들: ['설정', '안', '그냥', '무게', '재고', '자꾸', '설정', '무게', '짜증나다']
#
# 추출된 단어들: ['편평', '곳', '어도', '몸무게', '측정', '그냥', '환불', '부탁드리다']
#
# 추출된 단어들: ['없다']
#
# 추출된 단어들: ['오스', '람', '저가', '제품', '소음', '없다', '리모컨', '블루투스', '방식', '편리하다', '좋다', '프로', '이름', '걸', '원가', '절감', '티', '많다', '포장', '가격', '배', '가성', '비', '아쉽다', '샤오미', '가성', '비']
#
# 추출된 단어들: ['등록', '매우', '어렵다', '등록', '과정', '어렵다', '아니다', '자체', '인식', '율', '매우', '저조하다', '소비자', '등록', '절차', '어렵다', '분위기', '기기', '인식', '안되다', '정상', '절차', '진행', '실패', '오류', '계속', '뜸', '의사', '절대', '없다']
#
# 추출된 단어들: ['정말', '별로', '처음', '좋다', '은줄', '알', '어플', '서버', '불안정하다', '어플', '자체', '복구', '플러그', '작동', '아예', '먹통', '수동', '없다', '보고', '어플', '중앙', '제어', '깨', '잘못', '중앙', '서버', '뭐', '그냥', '벽돌', '복구', '이틀', '판매', '업체', '반품', '요청', '다시', '전화', '일주일', '연락', '없다', '전화통화', '연결', '안되다', '애플', '로그인', '로그아웃', '한번', '다시', '로그인', '화가', '애플', '로그인', '버튼', '순간', '비', '활성화', '지금', '로그인', '못', '카카오', '네이버', '연결', '못', '제품', '리셋', '몇번', '계정', '등록', '등록', '안되다', '시정', '이메일', '며칠', '아무', '대답', '없다', '서버', '도', '불안정하다', '디', '에스', '제품', '거르', '쓰시', '분', '계시다', '전', '별롭니', '전', '스마트', '플러그', '참고', '가격', '서비스', '상태', '사기', '돈', '아깝다']
#
# 추출된 단어들: ['연결', '자주', '어플', '오류', '어플', '등록', '제시', '해결', '방법', '정리', '안되다', '어플', '문제해결', '방법', '오류', '많다']
#
# 추출된 단어들: ['지난', '봄', '구입', '요', '안', '몸무게', '이상하다', '지금', '여자', '몸무게', '백', '이면', '체중', '못', '재고', '제품', '구입']
#
# 추출된 단어들: ['연동', '안되다', '설명', '대로', '몇번', '반복', '포기', '기대하다', '실망']
#
# 추출된 단어들: ['그냥', '리모컨', '그거', '가격', '명', '낚', '리모컨', '없다', '절대', '사용', '제품', '덜렁', '어쩌', '겁', '나중', '리모컨', '재주', '와이파이', '연결', '안되다', '둥', '문의', '많다', '그렇다', '사람', '헤깔리', '판매', '깔끔하다', '리모컨', '전용', '제품', '판매', '주의', '사항', '사람', '불편하다', '주문', '기업', '사훈', '낚시', '아니다', '판매', '이글', '관계자', '대충', '보고', '주문', '그렇다', '라며', '회사', '없다', '고객', '탓', '기업', '이윤', '추구', '눈', '고객', '입장', '생각', '기업', '누가', '좋아하다', '별', '미치다', '놈', '생각', '담']
#
# 추출된 단어들: ['안', '사지', '댓글알바']
#
# 추출된 단어들: ['설치', '후', '앱', '연동', '안되다', '유튜브', '온대', '해도', '불가', '돈']
#
# 추출된 단어들: ['힘', '강', '약하다', '불', '안되다']
#
# 추출된 단어들: ['진짜', '맘', '환불', '상자', '없다', '그냥', '제품', '분', '불량', '제품', '온건', '멋대로', '스마트', '전구', '전혀', '스마트']
#
# 추출된 단어들: ['기존', '체중', '고장', '새롭다', '신체', '나이', '살', '차이', '살', '머임', '고장', '나기', '전도', '인바디', '헬스장', '인바디', '재도', '후반', '살이', '처음', '불량', '아니다', '문의', '불량', '아니다', '박스', '절대', '반품', '불가능하다', '쪽', '고객', '센터', '초기', '불량', '제품', '도', '박스', '없다', '반품', '안되다', '없다', '오늘', '집', '문의', '파트너', '나중', '인바디', '미미하다', '반품', '반', '살이', '업', '미미하다', '차이', '요', '인바디', '체성', '육안', '신체', '나이', '아니다', '신체', '나이', '심각하다', '오차', '내용', '불량', '아니다', '요', '집', '환경', '사용자', '문제', '그렇다', '지금', '이전', '인바디', '헬스장', '인바디', '문제', '거', '업체', '응대', '미흡하다', '덕분', '투자', '블로그', '아주', '자세하다', '기재', '제품', '덕분', '페이지', '불친절하다', '응대', '때문', '널리', '널리', '퍼트', '리']
#
# 추출된 단어들: ['상자', '음성인식', '정작', '구글', '홈', '사용', '미니', '허브', '별도', '구매', '현재', '정도', '정도', '허위', '광고', '수준', '제품', '신뢰', '수', '의문', '요']
#
# 추출된 단어들: ['힘', '생각', '약하다', '아쉽다', '무용지물']
#
# 추출된 단어들: ['가격', '비싸다', '아주', '만족하다', '역', '방향', '수', '좋다']
#
# 추출된 단어들: ['배송', '지연', '사실', '오늘', '집', '구매', '물건', '중', '배송', '지연', '별로', '작다', '무게', '편이', '사이즈', '발', '발가락', '제외', '발바닥', '사이즈', '발', '정확하다', '측정', '건가']
#
# 추출된 단어들: ['소리', '가습기', '자꾸', '소리', '불', '리나', '놀랜', '번', '아니다', '계속', '연결', '안되다', '오늘', '원래', '그렇다', '원래', '모든', '가습기', '그렇다', '능', '건가', '전', '전혀', '그렇다', '안내', '사항', '상세', '페이지', '누가', '쿵쾅', '소리', '커서', '뻥', '안치', '누가', '집', '무섭다', '사용', '안', '원래', '그렇다', '물', '쉰내', '리뷰', '보고', '걸', '소비자', '센터', '서류', '제출', '예정', '후기', '도움', '좋다']

# %%
count_list = []

for words in extracted_words_list:
    count = Counter(words)
    count.most_common(100)
    count_list.append(count)

# %%
# 모든 Conter 객체를 합치기
total_counter = Counter()
for counter in count_list:
    total_counter += counter

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\Windows\Fonts\H2GTRE.TTF',
                     width = 700,
                     height = 700,
                     background_color = 'white',
                     colormap = 'spring',
                     random_state = 1).generate_from_frequencies(total_counter)

plt.figure(figsize=(10,10))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('word cloud', size=13)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 건강보험 수면장애 증가 시각화

# %%
import pandas as pd
import numpy as np
import chardet

# %%
with open('국민건강보험공단_수면장애(G47) 및 비기질성수면장애(F51) 진료인원_20221231.csv', 'rb') as f:
    data = f.read()

# %%
chardet.detect(data)

# %%
data = pd.read_csv('국민건강보험공단_수면장애(G47) 및 비기질성수면장애(F51) 진료인원_20221231.csv', encoding= 'EUC-KR')

# %%
data['진료인원(명)'] = data['진료인원(명)'].replace('NaN', np.nan)
data['진료인원(명)'] = data['진료인원(명)'].str.replace(',', '')
data['진료인원(명)'] = data['진료인원(명)'].astype('float64')

# %%
sleep  = round(data[['진료년도','진료인원(명)']].groupby(by='진료년도').sum()/10000,1)
