# %%
import pandas as pd

# %%
cnt = pd.Series([8740,5391] ,index=['긍정','부정'])
pct = pd.Series([0.618228,0.381772],index=['긍정','부정'])

# %%
pct
# Out:
# 긍정    0.618228
# 부정    0.381772
# dtype: float64

# %%
# 한글 폰트 적용
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

# %%
pct.plot(kind='pie', autopct='%.1f%%', ylabel='', startangle=90, counterclock=False,colormap = 'Pastel1')
# Out:
# <Axes: >

# %%
colors = ['#f1d1d2', '#9dbbd5']

# %%
cnt.plot(kind='bar',rot=0,colormap='Pastel1', ylim=(3000,10000),color=colors)
# Out:
# C:\Users\trainee223\AppData\Local\Temp\ipykernel_19568\1271776549.py:1: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   cnt.plot(kind='bar',rot=0,colormap='Pastel1', ylim=(3000,10000),color=colors)
# C:\Users\trainee223\AppData\Local\Temp\ipykernel_19568\1271776549.py:1: UserWarning: 'color' and 'colormap' cannot be used simultaneously. Using 'color'
#   cnt.plot(kind='bar',rot=0,colormap='Pastel1', ylim=(3000,10000),color=colors)
# <Axes: >
